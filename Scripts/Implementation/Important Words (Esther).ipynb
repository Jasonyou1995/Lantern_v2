# %% [markdown]
# ## Find important words in research articles about school violence

# %%
import pandas as pd
import nltk
import numpy as np
# %matplotlib inline  
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
import gensim
from gensim import corpora
from operator import itemgetter

# %%
#Take one txt file as an example
example_file = open('/Users/Esther/Lantern_v2/Data/fight_assault_data/Adolescent Assault Injury- Risk and Protective Factors and Locations of Contact for Intervention.txt', encoding = 'ISO-8859-1')

# %%
#Parse by sentences
import nltk.data
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
data = example_file.read()
docs = tokenizer.tokenize(data)

# %%
#Clean the input
stop = set(stopwords.words('english'))
stop.update(["this","these","many","may",'we','in','of','to','And','It',"It's","The",'the','abstract','background','them', '1','2','3','4','5','6','7','8','9'])
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()

def clean(doc):
    stop_free = " ".join([i.lower() for i in str(doc).split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

# %%
#build dictionary and term matrix
doc_clean = [clean(doc).split() for doc in docs]
dictionary = corpora.Dictionary(doc_clean)
dictionary.filter_extremes(no_above=0.1)
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]

#Words in the dictionary sorted by the number of time it appeared in the doc
sorted_dict = sorted(dictionary.token2id.items(), key=lambda x: x[1], reverse = True)
sorted_dict
# Out:
# [('screening', 102),
#  ('our', 101),
#  ('lifetime', 100),
#  ('history', 99),
#  ('home', 98),
#  ('of', 97),
#  ('data', 96),
#  ('used', 95),
#  ('behavioral', 94),
#  ('including', 93),
#  ('community', 92),
#  ('social', 91),
#  ('using', 90),
#  ('question', 89),
#  ('audiotape', 88),
#  ('in', 87),
#  ('consent', 86),
#  ('analysis', 85),
#  ('time', 84),
#  ('uninjured', 83),
#  ('possible', 82),
#  ('found', 81),
#  ('research', 80),
#  ('patient', 79),
#  ('table', 78),
#  ('hospitalized', 77),
#  ('we', 76),
#  ('sexual', 75),
#  ('included', 74),
#  ('hospital', 73),
#  ('population', 72),
#  ('primary', 71),
#  ('predictive', 70),
#  ('comparison', 69),
#  ('problem', 68),
#  ('individual', 67),
#  ('association', 66),
#  ('exposure', 65),
#  ('use', 64),
#  ('these', 63),
#  ('behavior', 62),
#  ('high', 61),
#  ('potential', 60),
#  ('ed', 59),
#  ('for', 58),
#  ('number', 57),
#  ('include', 56),
#  ('this', 55),
#  ('however', 54),
#  ('assessment', 53),
#  ('highrisk', 52),
#  ('fighting', 51),
#  ('weaponcarrying', 50),
#  ('access', 49),
#  ('school', 48),
#  ('involvement', 47),
#  ('activity', 46),
#  ('extracurricular', 45),
#  ('difference', 44),
#  ('there', 43),
#  ('provider', 42),
#  ('health', 41),
#  ('regular', 40),
#  ('someone', 39),
#  ('previous', 38),
#  ('last', 37),
#  ('medical', 36),
#  ('ci', 35),
#  ('95', 34),
#  ('or', 33),
#  ('past', 32),
#  ('fight', 31),
#  ('likely', 30),
#  ('noninjured', 29),
#  ('injured', 28),
#  ('result', 27),
#  ('race', 26),
#  ('gender', 25),
#  ('age', 24),
#  ('matched', 23),
#  ('year', 22),
#  ('12', 21),
#  ('interview', 20),
#  ('phone', 19),
#  ('prevention', 18),
#  ('2', 17),
#  ('presenting', 16),
#  ('complaint', 15),
#  ('unintentional', 14),
#  ('compared', 13),
#  ('ass', 12),
#  ('1', 11),
#  ('atrisk', 10),
#  ('associated', 9),
#  ('casecontrol', 8),
#  ('conducted', 7),
#  ('to', 6),
#  ('violent', 5),
#  ('among', 4),
#  ('intervention', 3),
#  ('contact', 2),
#  ('location', 1),
#  ('protective', 0)]

# %%
#tfidf using gensim package
tfidf = gensim.models.tfidfmodel.TfidfModel(doc_term_matrix, id2word = dictionary)

# %%
#Fit corpus to get scores for terms in dictionary
corpus_tfidf = tfidf[doc_term_matrix]
word_score = {dictionary.get(id): value for doc in corpus_tfidf for id, value in doc}
#print(word_score)

# %%
#Sort by term scores
import operator
sorted_word_score = sorted(word_score.items(), key=operator.itemgetter(1),reverse=True)
sorted_word_score
# Out:
# [('in', 0.7876250651812999),
#  ('of', 0.7876250651812999),
#  ('age', 0.7769293634413851),
#  ('hospitalized', 0.768956907018393),
#  ('behavior', 0.6827990356238554),
#  ('question', 0.6591676699681592),
#  ('interview', 0.6383459899771748),
#  ('high', 0.619745151812437),
#  ('population', 0.6130089543656961),
#  ('atrisk', 0.6081270403165475),
#  ('lifetime', 0.6055986595372576),
#  ('involvement', 0.6032694783408777),
#  ('to', 0.5951937190408129),
#  ('predictive', 0.5951937190408129),
#  ('conducted', 0.5870329427340855),
#  ('result', 0.5870329427340855),
#  ('school', 0.5870080464068823),
#  ('exposure', 0.5712786894992368),
#  ('use', 0.5592533523746622),
#  ('potential', 0.5448094811442676),
#  ('individual', 0.5444900551837686),
#  ('prevention', 0.5398970954068303),
#  ('include', 0.5365575079396265),
#  ('matched', 0.5334255436892335),
#  ('consent', 0.527714856455989),
#  ('among', 0.5213860880967386),
#  ('weaponcarrying', 0.5213860880967386),
#  ('these', 0.5137843667023391),
#  ('used', 0.49820766181522225),
#  ('95', 0.49524891990043857),
#  ('associated', 0.4938920544614837),
#  ('behavioral', 0.48888762837254557),
#  ('ci', 0.4767406448193263),
#  ('fighting', 0.47381713524888347),
#  ('analysis', 0.473126972839839),
#  ('community', 0.4708092149913663),
#  ('1', 0.4666322538152466),
#  ('race', 0.4660702280893824),
#  ('comparison', 0.4660702280893824),
#  ('hospital', 0.4581501079702953),
#  ('home', 0.4544551707763449),
#  ('we', 0.4542735276485399),
#  ('extracurricular', 0.4509829646364023),
#  ('there', 0.4432287278946779),
#  ('gender', 0.44260739656887654),
#  ('problem', 0.4404058521447315),
#  ('association', 0.4341519118353192),
#  ('this', 0.43408661541332494),
#  ('or', 0.4315346531145825),
#  ('activity', 0.43076457161562687),
#  ('phone', 0.4155855558289702),
#  ('casecontrol', 0.4083140283475513),
#  ('uninjured', 0.390906620316815),
#  ('regular', 0.38852614334544455),
#  ('medical', 0.38721712061675834),
#  ('health', 0.3796154659993993),
#  ('location', 0.374363985409108),
#  ('however', 0.3734583629430128),
#  ('assessment', 0.3734406469322977),
#  ('research', 0.3656772825216737),
#  ('audiotape', 0.3656772825216737),
#  ('contact', 0.35229045076175297),
#  ('primary', 0.35229045076175297),
#  ('possible', 0.34749246754125357),
#  ('table', 0.34726841631742217),
#  ('complaint', 0.3393237312093811),
#  ('ass', 0.33763469044290534),
#  ('intervention', 0.3333819551297117),
#  ('someone', 0.332528372028889),
#  ('ed', 0.3248542182276678),
#  ('including', 0.3206375398422006),
#  ('history', 0.3206375398422006),
#  ('presenting', 0.31842669115951056),
#  ('2', 0.3182213805513132),
#  ('provider', 0.3102247586141008),
#  ('difference', 0.30764169961334437),
#  ('data', 0.30650447718284807),
#  ('our', 0.30650447718284807),
#  ('screening', 0.30650447718284807),
#  ('using', 0.30626665377530515),
#  ('violent', 0.30163473917043887),
#  ('highrisk', 0.2910744787083634),
#  ('time', 0.2845523435402604),
#  ('patient', 0.2797741956898062),
#  ('sexual', 0.27301519495589704),
#  ('included', 0.2682928880401033),
#  ('number', 0.2667277474873037),
#  ('social', 0.26579108624467546),
#  ('access', 0.2641297866234904),
#  ('for', 0.2641297866234904),
#  ('last', 0.25811593579343306),
#  ('previous', 0.2567596883479665),
#  ('12', 0.24739841194821743),
#  ('noninjured', 0.23009221429496035),
#  ('compared', 0.2236535351142149),
#  ('unintentional', 0.21576732655729125),
#  ('fight', 0.20806622590584717),
#  ('likely', 0.20112025026216684),
#  ('injured', 0.19353843550007804),
#  ('year', 0.19316433070491926),
#  ('past', 0.18759463821823583),
#  ('found', 0.1818451570480817),
#  ('protective', 0.17178452795173715)]

# %%
#tfidf using sklearn package
from sklearn.feature_extraction.text import TfidfVectorizer
tf = TfidfVectorizer(analyzer='word', ngram_range=(1,3), min_df = 0, stop_words = stop)
tfidf_matrix =  tf.fit_transform(docs)
feature_names = tf.get_feature_names() 
len(feature_names)
# Out:
# 47730

# %%
#print(feature_names)

# %%
#sort term scores
dense = tfidf_matrix.todense()
sentences = dense[0].tolist()[0]
phrase_scores = [pair for pair in zip(range(0, len(sentences)), sentences) if pair[1] > 0]
#sorted(phrase_scores, key=lambda t: t[1] * -1)
# Out:
# [(23489, 0.26529856946874675),
#  (6127, 0.25146900823927426),
#  (11607, 0.25146900823927426),
#  (17580, 0.25146900823927426),
#  (17581, 0.25146900823927426),
#  (23487, 0.25146900823927426),
#  (25842, 0.25146900823927426),
#  (33366, 0.25146900823927426),
#  (3363, 0.23404582163163482),
#  (3361, 0.22256946200088382),
#  (25840, 0.22256946200088382),
#  (25839, 0.20145533783852984),
#  (11598, 0.19657446932594275),
#  (36545, 0.18199525385953136),
#  (36543, 0.1805436350106156),
#  (6110, 0.1752858798484447),
#  (33349, 0.17181428642422203),
#  (33344, 0.1676749230875523),
#  (23960, 0.15619856345680128),
#  (3348, 0.14452390155383932),
#  (17425, 0.12344782301142943),
#  (23314, 0.12214084722112573),
#  (6054, 0.11478730975565171),
#  (36350, 0.10575920397671404)]

# %%
#Match term ID with term
sorted_phrase_scores = sorted(phrase_scores, key=lambda t: t[1] * -1)
for phrase, score in [(feature_names[word_id], score) for (word_id, score) in sorted_phrase_scores][:20]:
    print('{0: <20} {1}'.format(phrase, score))
# Out:
# injury risk protective 0.26529856946874675
# assault injury risk  0.25146900823927426
# contact intervention 0.25146900823927426
# factors locations    0.25146900823927426
# factors locations contact 0.25146900823927426
# injury risk          0.25146900823927426
# locations contact intervention 0.25146900823927426
# protective factors locations 0.25146900823927426
# adolescent assault injury 0.23404582163163482
# adolescent assault   0.22256946200088382
# locations contact    0.22256946200088382
# locations            0.20145533783852984
# contact              0.19657446932594275
# risk protective factors 0.18199525385953136
# risk protective      0.1805436350106156
# assault injury       0.1752858798484447
# protective factors   0.17181428642422203
# protective           0.1676749230875523
# intervention         0.15619856345680128
# adolescent           0.14452390155383932

# %% [markdown]
# ## Combine files for each type of violence

# %%
#Fight_assault_data
import glob
path =r'/Users/Esther/Lantern_v2/Data/fight_assault_data/'
allFiles = glob.glob(path + "/*.txt")
text = ''
for file_ in allFiles:
    with open(file_, encoding="latin-1") as f:
        text = text + str(f.read())

# %%
texts = tokenizer.tokenize(text)
texts_clean = [clean(doc).split() for doc in texts]
dictionary = corpora.Dictionary(texts_clean)
dictionary.filter_extremes(no_above=0.5)
doc_term_matrix = [dictionary.doc2bow(doc) for doc in texts_clean]

#Words in the dictionary sorted by the number of time it appeared in the doc
sorted_dict = sorted(dictionary.token2id.items(), key=lambda x: x[1], reverse = True)
sorted_dict
# Out:
# [('team', 1105),
#  ('perone', 1104),
#  ('hyman', 1103),
#  ('dwyer', 1102),
#  ('leone', 1101),
#  ('mayer', 1100),
#  ('soriano', 1099),
#  ('harmful', 1098),
#  ('hoover', 1097),
#  ('craig', 1096),
#  ('cultural', 1095),
#  ('oak', 1094),
#  ('oliver', 1093),
#  ('brockenbrough', 1092),
#  ('bulach', 1091),
#  ('skiba', 1090),
#  ('studer', 1089),
#  ('eisenbraun', 1088),
#  ('kd', 1087),
#  ('morrison', 1086),
#  ('furlong', 1085),
#  ('osofsky', 1084),
#  ('cited', 1083),
#  ('heaviside', 1082),
#  ('459ð469', 1081),
#  ('2007', 1080),
#  ('kid', 1079),
#  ('economic', 1078),
#  ('human', 1077),
#  ('combined', 1076),
#  ('hbsc', 1075),
#  ('crossnational', 1074),
#  ('prevalent', 1073),
#  ('canadian', 1072),
#  ('studentsõ', 1071),
#  ('canada', 1070),
#  ('think', 1069),
#  ('fear', 1068),
#  ('america', 1067),
#  ('retaliate', 1066),
#  ('ivr', 1065),
#  ('mediating', 1064),
#  ('spsir', 1063),
#  ('dysfunctional', 1062),
#  ('solve', 1061),
#  ('nezu', 1060),
#  ('dõzurilla', 1059),
#  ('view', 1058),
#  ('instrumental', 1057),
#  ('aq', 1056),
#  ('multidimensional', 1055),
#  ('peterson', 1054),
#  ('baumeister', 1053),
#  ('1992', 1052),
#  ('perry', 1051),
#  ('understood', 1050),
#  ('mediates', 1049),
#  ('path', 1048),
#  ('hostility', 1047),
#  ('avoidance', 1046),
#  ('impulsivitycarelessness', 1045),
#  ('solving', 1044),
#  ('selfesteem', 1043),
#  ('goal', 1042),
#  ('therapist', 1041),
#  ('feel', 1040),
#  ('authority', 1039),
#  ('making', 1038),
#  ('standardized', 1037),
#  ('agent', 1036),
#  ('longer', 1035),
#  ('psychologist', 1034),
#  ('problemsolving', 1033),
#  ('cbt', 1032),
#  ('extremely', 1031),
#  ('done', 1030),
#  ('expected', 1029),
#  ('rational', 1028),
#  ('medication', 1027),
#  ('incidence', 1026),
#  ('involves', 1025),
#  ('deficit', 1024),
#  ('investigation', 1023),
#  ('parenting', 1022),
#  ('cohort', 1021),
#  ('progress', 1020),
#  ('distinct', 1019),
#  ('belief', 1018),
#  ('stability', 1017),
#  ('efficacy', 1016),
#  ('vary', 1015),
#  ('amount', 1014),
#  ('olweus', 1013),
#  ('socially', 1012),
#  ('learn', 1011),
#  ('monitoring', 1010),
#  ('responsibility', 1009),
#  ('negative', 1008),
#  ('punishment', 1007),
#  ('believe', 1006),
#  ('solution', 1005),
#  ('tendency', 1004),
#  ('rejection', 1003),
#  ('communication', 1002),
#  ('specifically', 1001),
#  ('correlation', 1000),
#  ('testosterone', 999),
#  ('nonaggressive', 998),
#  ('prepubertal', 997),
#  ('functioning', 996),
#  ('demonstrate', 995),
#  ('fully', 994),
#  ('attachment', 993),
#  ('al', 992),
#  ('yet', 991),
#  ('arousal', 990),
#  ('affective', 989),
#  ('anxiety', 988),
#  ('correlated', 987),
#  ('cortisol', 986),
#  ('turn', 985),
#  ('possibility', 984),
#  ('focusing', 983),
#  ('comorbid', 982),
#  ('consider', 981),
#  ('link', 980),
#  ('offender', 979),
#  ('linked', 978),
#  ('according', 977),
#  ('later', 976),
#  ('intent', 975),
#  ('affect', 974),
#  ('impaired', 973),
#  ('tend', 972),
#  ('clinically', 971),
#  ('difficulty', 970),
#  ('prenatal', 969),
#  ('challenge', 968),
#  ('diverse', 967),
#  ('relatively', 966),
#  ('search', 965),
#  ('emphasis', 964),
#  ('perspective', 963),
#  ('success', 962),
#  ('established', 961),
#  ('course', 960),
#  ('onset', 959),
#  ('consideration', 958),
#  ('cumulative', 957),
#  ('carefully', 956),
#  ('evaluating', 955),
#  ('still', 954),
#  ('disruptive', 953),
#  ('clinician', 952),
#  ('psychiatric', 951),
#  ('adolescence', 950),
#  ('usually', 949),
#  ('respond', 948),
#  ('vulnerable', 947),
#  ('stress', 946),
#  ('certain', 945),
#  ('long', 944),
#  ('appears', 943),
#  ('harsh', 942),
#  ('trajectory', 941),
#  ('committed', 940),
#  ('remain', 939),
#  ('subtypes', 938),
#  ('considered', 937),
#  ('motivation', 936),
#  ('physiological', 935),
#  ('pathway', 934),
#  ('developmental', 933),
#  ('empirical', 932),
#  ('diagnostic', 931),
#  ('make', 930),
#  ('useful', 929),
#  ('like', 928),
#  ('therapy', 927),
#  ('effectiveness', 926),
#  ('play', 925),
#  ('serotonin', 924),
#  ('showed', 923),
#  ('referral', 922),
#  ('perpetrator', 921),
#  ('interaction', 920),
#  ('impairment', 919),
#  ('psychosocial', 918),
#  ('frequently', 917),
#  ('controlled', 916),
#  ('carrying', 915),
#  ('both', 914),
#  ('followup', 913),
#  ('1999', 912),
#  ('1997', 911),
#  ('depression', 910),
#  ('001', 909),
#  ('neighborhood', 908),
#  ('highest', 907),
#  ('always', 906),
#  ('initially', 905),
#  ('distribution', 904),
#  ('dependent', 903),
#  ('controlling', 902),
#  ('socioeconomic', 901),
#  ('structure', 900),
#  ('et', 899),
#  ('coefficient', 898),
#  ('vulnerability', 897),
#  ('0', 896),
#  ('1996', 895),
#  ('respondent', 894),
#  ('dynamic', 893),
#  ('from', 892),
#  ('questionnaire', 891),
#  ('1995', 890),
#  ('stratified', 889),
#  ('random', 888),
#  ('detailed', 887),
#  ('characterized', 886),
#  ('addition', 885),
#  ('antisocial', 884),
#  ('derived', 883),
#  ('earlier', 882),
#  ('committing', 881),
#  ('1993', 880),
#  ('1994', 879),
#  ('record', 878),
#  ('arrest', 877),
#  ('juvenile', 876),
#  ('dimension', 875),
#  ('symptom', 874),
#  ('perceived', 873),
#  ('whereas', 872),
#  ('nationally', 871),
#  ('girl', 870),
#  ('predict', 869),
#  ('exist', 868),
#  ('better', 867),
#  ('occurrence', 866),
#  ('become', 865),
#  ('technique', 864),
#  ('educational', 863),
#  ('resource', 862),
#  ('reflect', 861),
#  ('understanding', 860),
#  ('define', 859),
#  ('implement', 858),
#  ('tool', 857),
#  ('justice', 856),
#  ('plan', 855),
#  ('decrease', 854),
#  ('effectively', 853),
#  ('reactive', 852),
#  ('detail', 851),
#  ('conduct', 850),
#  ('independent', 849),
#  ('b', 848),
#  ('demonstrated', 847),
#  ('simply', 846),
#  ('educ', 845),
#  ('lansing', 844),
#  ('occurs', 843),
#  ('providing', 842),
#  ('purpose', 841),
#  ('promote', 840),
#  ('serve', 839),
#  ('relevant', 838),
#  ('going', 837),
#  ('harm', 836),
#  ('requires', 835),
#  ('federal', 834),
#  ('ensuring', 833),
#  ('safe', 832),
#  ('determined', 831),
#  ('right', 830),
#  ('request', 829),
#  ('leave', 828),
#  ('court', 827),
#  ('held', 826),
#  ('andor', 825),
#  ('longterm', 824),
#  ('third', 823),
#  ('criminal', 822),
#  ('includes', 821),
#  ('¤', 820),
#  ('instance', 819),
#  ('commit', 818),
#  ('texas', 817),
#  ('disciplinary', 816),
#  ('problematic', 815),
#  ('17', 814),
#  ('4', 813),
#  ('place', 812),
#  ('indicate', 811),
#  ('50', 810),
#  ('6', 809),
#  ('7', 808),
#  ('larger', 807),
#  ('grade', 806),
#  ('u', 805),
#  ('culture', 804),
#  ('direct', 803),
#  ('carry', 802),
#  ('discipline', 801),
#  ('rule', 800),
#  ('shooting', 799),
#  ('nature', 798),
#  ('add', 797),
#  ('false', 796),
#  ('list', 795),
#  ('possession', 794),
#  ('little', 793),
#  ('attack', 792),
#  ('stop', 791),
#  ('new', 790),
#  ('north', 789),
#  ('security', 788),
#  ('since', 787),
#  ('elementary', 786),
#  ('regarding', 785),
#  ('official', 784),
#  ('clear', 783),
#  ('four', 782),
#  ('warning', 781),
#  ('he', 780),
#  ('directed', 779),
#  ('seattle', 778),
#  ('principal', 777),
#  ('physically', 776),
#  ('while', 775),
#  ('manual', 774),
#  ('key', 773),
#  ('attrition', 772),
#  ('absence', 771),
#  ('safety', 770),
#  ('duty', 769),
#  ('action', 768),
#  ('statute', 767),
#  ('moreover', 766),
#  ('driver', 765),
#  ('bus', 764),
#  ('enforcement', 763),
#  ('administrator', 762),
#  ('not', 761),
#  ('incident', 760),
#  ('numerous', 759),
#  ('percentage', 758),
#  ('educator', 757),
#  ('minnesota', 756),
#  ('act', 755),
#  ('scholar', 754),
#  ('crisishttpwwwapaorgedschoolscpseactivitiesviolenceagainstaspxêgoogle', 753),
#  ('associationê2013', 752),
#  ('associationê2013american', 751),
#  ('psychological', 750),
#  ('silent', 749),
#  ('teacher', 748),
#  ('classroom', 747),
#  ('campus', 746),
#  ('look', 745),
#  ('major', 744),
#  ('employee', 743),
#  ('workplace', 742),
#  ('highly', 741),
#  ('personnel', 740),
#  ('set', 739),
#  ('policy', 738),
#  ('ineffective', 737),
#  ('survival', 736),
#  ('despite', 735),
#  ('rather', 734),
#  ('appear', 733),
#  ('complex', 732),
#  ('recognition', 731),
#  ('simple', 730),
#  ('range', 729),
#  ('based', 728),
#  ('reducing', 727),
#  ('indicator', 726),
#  ('positive', 725),
#  ('practice', 724),
#  ('led', 723),
#  ('implementation', 722),
#  ('life', 721),
#  ('reduction', 720),
#  ('2002', 719),
#  ('improvement', 718),
#  ('three', 717),
#  ('either', 716),
#  ('randomized', 715),
#  ('younger', 714),
#  ('imci', 713),
#  ('c', 712),
#  ('law', 711),
#  ('e', 710),
#  ('trial', 709),
#  ('bangladesh', 708),
#  ('area', 707),
#  ('rural', 706),
#  ('nutrition', 705),
#  ('integrated', 704),
#  ('effect', 703),
#  ('r', 702),
#  ('heightened', 701),
#  ('awareness', 700),
#  ('observed', 699),
#  ('42', 698),
#  ('average', 697),
#  ('estimated', 696),
#  ('primarily', 695),
#  ('relative', 694),
#  ('2003', 693),
#  ('participated', 692),
#  ('country', 691),
#  ('five', 690),
#  ('sv', 689),
#  ('pv', 688),
#  ('examine', 687),
#  ('d', 686),
#  ('student', 685),
#  ('global', 684),
#  ('behaviour', 683),
#  ('them', 682),
#  ('estimate', 681),
#  ('reliability', 680),
#  ('suburban', 679),
#  ('single', 678),
#  ('help', 677),
#  ('alternative', 676),
#  ('anger', 675),
#  ('skill', 674),
#  ('coping', 673),
#  ('and', 672),
#  ('provides', 671),
#  ('developing', 670),
#  ('recent', 669),
#  ('situation', 668),
#  ('men', 667),
#  ('minority', 666),
#  ('medium', 665),
#  ('cycle', 664),
#  ('break', 663),
#  ('provide', 662),
#  ('subsequent', 661),
#  ('boy', 660),
#  ('particularly', 659),
#  ('indicates', 658),
#  ('schoolbased', 657),
#  ('exposed', 656),
#  ('directly', 655),
#  ('term', 654),
#  ('cost', 653),
#  ('sustained', 652),
#  ('prospective', 651),
#  ('additional', 650),
#  ('experienced', 649),
#  ('work', 648),
#  ('process', 647),
#  ('bullying', 646),
#  ('personal', 645),
#  ('11', 644),
#  ('mood', 643),
#  ('system', 642),
#  ('overall', 641),
#  ('firearm', 640),
#  ('involving', 639),
#  ('selfreported', 638),
#  ('ie', 637),
#  ('immediately', 636),
#  ('88', 635),
#  ('acceptable', 634),
#  ('multivariate', 633),
#  ('various', 632),
#  ('evaluation', 631),
#  ('approximately', 630),
#  ('attitude', 629),
#  ('32', 628),
#  ('v', 627),
#  ('particular', 626),
#  ('college', 625),
#  ('they', 624),
#  ('note', 623),
#  ('go', 622),
#  ('evidence', 621),
#  ('provided', 620),
#  ('severe', 619),
#  ('building', 618),
#  ('versus', 617),
#  ('statistic', 616),
#  ('bivariate', 615),
#  ('l', 614),
#  ('standard', 613),
#  ('categorized', 612),
#  ('mechanism', 611),
#  ('aggressive', 610),
#  ('relationship', 609),
#  ('following', 608),
#  ('line', 607),
#  ('index', 606),
#  ('disorder', 605),
#  ('scale', 604),
#  ('indicated', 603),
#  ('score', 602),
#  ('environmental', 601),
#  ('aggression', 600),
#  ('toward', 599),
#  ('required', 598),
#  ('taken', 597),
#  ('collected', 596),
#  ('education', 595),
#  ('ethnicity', 594),
#  ('see', 593),
#  ('received', 592),
#  ('72', 591),
#  ('due', 590),
#  ('orientation', 589),
#  ('cognitive', 588),
#  ('attempt', 587),
#  ('chief', 586),
#  ('female', 585),
#  ('2009', 584),
#  ('ra', 583),
#  ('along', 582),
#  ('michigan', 581),
#  ('university', 580),
#  ('crime', 579),
#  ('african', 578),
#  ('treated', 577),
#  ('examining', 576),
#  ('article', 575),
#  ('design', 574),
#  ('describe', 573),
#  ('cannot', 572),
#  ('limit', 571),
#  ('available', 570),
#  ('peer', 569),
#  ('with', 568),
#  ('got', 567),
#  ('understand', 566),
#  ('importance', 565),
#  ('develop', 564),
#  ('trauma', 563),
#  ('typically', 562),
#  ('focused', 561),
#  ('researcher', 560),
#  ('instead', 559),
#  ('information', 558),
#  ('preventing', 557),
#  ('style', 556),
#  ('change', 555),
#  ('often', 554),
#  ('several', 553),
#  ('victim', 552),
#  ('intervene', 551),
#  ('homicide', 550),
#  ('admitted', 549),
#  ('20', 548),
#  ('assaultrelated', 547),
#  ('2011', 546),
#  ('prevent', 545),
#  ('therefore', 544),
#  ('people', 543),
#  ('5', 542),
#  ('almost', 541),
#  ('misuse', 540),
#  ('reason', 539),
#  ('experience', 538),
#  ('retaliation', 537),
#  ('caused', 536),
#  ('commonly', 535),
#  ('street', 534),
#  ('occurred', 533),
#  ('sampled', 532),
#  ('total', 531),
#  ('membership', 530),
#  ('edbased', 529),
#  ('inform', 528),
#  ('utilization', 527),
#  ('seeking', 526),
#  ('crucial', 525),
#  ('another', 524),
#  ('strength', 523),
#  ('knowledge', 522),
#  ('needed', 521),
#  ('difficult', 520),
#  ('limited', 519),
#  ('threat', 518),
#  ('t', 517),
#  ('s', 516),
#  ('i', 515),
#  ('example', 514),
#  ('management', 513),
#  ('assist', 512),
#  ('setting', 511),
#  ('get', 510),
#  ('ability', 509),
#  ('24', 508),
#  ('even', 507),
#  ('strong', 506),
#  ('severity', 505),
#  ('increasing', 504),
#  ('claim', 503),
#  ('least', 502),
#  ('fightrelated', 501),
#  ('remained', 500),
#  ('current', 499),
#  ('value', 498),
#  ('brought', 497),
#  ('clearly', 496),
#  ('predictor', 495),
#  ('some', 494),
#  ('part', 493),
#  ('suggests', 492),
#  ('way', 491),
#  ('interact', 490),
#  ('environment', 489),
#  ('personality', 488),
#  ('characteristic', 487),
#  ('biological', 486),
#  ('point', 485),
#  ('world', 484),
#  ('center', 483),
#  ('cluster', 482),
#  ('theory', 481),
#  ('consistent', 480),
#  ('increased', 479),
#  ('higher', 478),
#  ('suggestion', 477),
#  ('insight', 476),
#  ('offer', 475),
#  ('examined', 474),
#  ('relation', 473),
#  ('performance', 472),
#  ('level', 471),
#  ('studied', 470),
#  ('sensitivity', 469),
#  ('finding', 468),
#  ('explanation', 467),
#  ('tested', 466),
#  ('small', 465),
#  ('discussed', 464),
#  ('best', 463),
#  ('inconsistent', 462),
#  ('violencerelated', 461),
#  ('status', 460),
#  ('followed', 459),
#  ('longitudinal', 458),
#  ('screening', 457),
#  ('benefit', 456),
#  ('influence', 455),
#  ('combination', 454),
#  ('adult', 453),
#  ('young', 452),
#  ('potentially', 451),
#  ('need', 450),
#  ('highlight', 449),
#  ('different', 448),
#  ('14', 447),
#  ('proportion', 446),
#  ('although', 445),
#  ('opportunity', 444),
#  ('majority', 443),
#  ('critical', 442),
#  ('effective', 441),
#  ('active', 440),
#  ('implication', 439),
#  ('finally', 438),
#  ('though', 437),
#  ('acute', 436),
#  ('representative', 435),
#  ('second', 434),
#  ('our', 433),
#  ('profile', 432),
#  ('hypothesis', 431),
#  ('able', 430),
#  ('lead', 429),
#  ('fact', 428),
#  ('other', 427),
#  ('well', 426),
#  ('statistical', 425),
#  ('specific', 424),
#  ('nonetheless', 423),
#  ('lower', 422),
#  ('shown', 421),
#  ('noted', 420),
#  ('low', 419),
#  ('others', 418),
#  ('greater', 417),
#  ('suggested', 416),
#  ('consistency', 415),
#  ('internal', 414),
#  ('face', 413),
#  ('concern', 412),
#  ('persistent', 411),
#  ('issue', 410),
#  ('selection', 409),
#  ('related', 408),
#  ('interviewing', 407),
#  ('selfreport', 406),
#  ('validity', 405),
#  ('limitation', 404),
#  ('could', 403),
#  ('also', 402),
#  ('living', 401),
#  ('physical', 400),
#  ('prevalence', 399),
#  ('discussion', 398),
#  ('assaulted', 397),
#  ('threatened', 396),
#  ('gang', 395),
#  ('power', 394),
#  ('per', 393),
#  ('size', 392),
#  ('lifetime', 391),
#  ('partner', 390),
#  ('significantly', 389),
#  ('history', 388),
#  ('alcohol', 387),
#  ('cigarette', 386),
#  ('smoking', 385),
#  ('selected', 384),
#  ('reported', 383),
#  ('more', 382),
#  ('prosocial', 381),
#  ('type', 380),
#  ('present', 379),
#  ('p', 378),
#  ('presence', 377),
#  ('home', 376),
#  ('black', 375),
#  ('15', 374),
#  ('mean', 373),
#  ('26', 372),
#  ('category', 371),
#  ('across', 370),
#  ('significant', 369),
#  ('feeling', 368),
#  ('interest', 367),
#  ('participate', 366),
#  ('defined', 365),
#  ('on', 364),
#  ('knife', 363),
#  ('gun', 362),
#  ('13', 361),
#  ('successfully', 360),
#  ('80', 359),
#  ('of', 358),
#  ('show', 357),
#  ('figure', 356),
#  ('evaluate', 355),
#  ('obtain', 354),
#  ('regression', 353),
#  ('logistic', 352),
#  ('take', 351),
#  ('item', 350),
#  ('measured', 349),
#  ('above', 348),
#  ('described', 347),
#  ('thus', 346),
#  ('outcome', 345),
#  ('increase', 344),
#  ('effort', 343),
#  ('order', 342),
#  ('variable', 341),
#  ('sex', 340),
#  ('sampling', 339),
#  ('institute', 338),
#  ('data', 337),
#  ('instrument', 336),
#  ('developed', 335),
#  ('a', 334),
#  ('testretest', 333),
#  ('good', 332),
#  ('middle', 331),
#  ('used', 330),
#  ('city', 329),
#  ('service', 328),
#  ('source', 327),
#  ('survey', 326),
#  ('national', 325),
#  ('frequency', 324),
#  ('3', 323),
#  ('ideation', 322),
#  ('emotional', 321),
#  ('substance', 320),
#  ('behavioral', 319),
#  ('demographic', 318),
#  ('including', 317),
#  ('community', 316),
#  ('social', 315),
#  ('assessed', 314),
#  ('initial', 313),
#  ('16', 312),
#  ('measure', 311),
#  ('training', 310),
#  ('extensive', 309),
#  ('model', 308),
#  ('using', 307),
#  ('participant', 306),
#  ('bias', 305),
#  ('likelihood', 304),
#  ('event', 303),
#  ('quickly', 302),
#  ('complete', 301),
#  ('asked', 300),
#  ('question', 299),
#  ('audiotape', 298),
#  ('response', 297),
#  ('verbal', 296),
#  ('component', 295),
#  ('person', 294),
#  ('in', 293),
#  ('18', 292),
#  ('minor', 291),
#  ('if', 290),
#  ('obtained', 289),
#  ('consent', 288),
#  ('procedure', 287),
#  ('next', 286),
#  ('enrollment', 285),
#  ('all', 284),
#  ('analysis', 283),
#  ('time', 282),
#  ('enrolled', 281),
#  ('chronic', 280),
#  ('excluded', 279),
#  ('episode', 278),
#  ('eg', 277),
#  ('uninjured', 276),
#  ('would', 275),
#  ('designed', 274),
#  ('recruitment', 273),
#  ('family', 272),
#  ('made', 271),
#  ('when', 270),
#  ('possible', 269),
#  ('discharge', 268),
#  ('member', 267),
#  ('staff', 266),
#  ('attempted', 265),
#  ('serious', 264),
#  ('because', 263),
#  ('90', 262),
#  ('found', 261),
#  ('surveillance', 260),
#  ('hour', 259),
#  ('week', 258),
#  ('day', 257),
#  ('assistant', 256),
#  ('research', 255),
#  ('patient', 254),
#  ('presented', 253),
#  ('eligible', 252),
#  ('identified', 251),
#  ('table', 250),
#  ('criterion', 249),
#  ('board', 248),
#  ('review', 247),
#  ('institutional', 246),
#  ('approved', 245),
#  ('protocol', 244),
#  ('private', 243),
#  ('1998', 242),
#  ('academic', 241),
#  ('2000', 240),
#  ('period', 239),
#  ('hospitalized', 238),
#  ('recruited', 237),
#  ('we', 236),
#  ('sought', 235),
#  ('represent', 234),
#  ('illness', 233),
#  ('two', 232),
#  ('code', 231),
#  ('disease', 230),
#  ('international', 229),
#  ('legal', 228),
#  ('abuse', 227),
#  ('sexual', 226),
#  ('interpersonal', 225),
#  ('included', 224),
#  ('hospital', 223),
#  ('urban', 222),
#  ('subject', 221),
#  ('population', 220),
#  ('strategy', 219),
#  ('appropriate', 218),
#  ('might', 217),
#  ('whether', 216),
#  ('address', 215),
#  ('primary', 214),
#  ('perpetration', 213),
#  ('identification', 212),
#  ('involved', 211),
#  ('professional', 210),
#  ('organization', 209),
#  ('american', 208),
#  ('step', 207),
#  ('important', 206),
#  ('predictive', 205),
#  ('identifying', 204),
#  ('comparison', 203),
#  ('without', 202),
#  ('unfortunately', 201),
#  ('multiple', 200),
#  ('basis', 199),
#  ('form', 198),
#  ('an', 197),
#  ('contribute', 196),
#  ('suggest', 195),
#  ('strongly', 194),
#  ('report', 193),
#  ('2001', 192),
#  ('literature', 191),
#  ('early', 190),
#  ('problem', 189),
#  ('approach', 188),
#  ('preventive', 187),
#  ('proactive', 186),
#  ('advocate', 185),
#  ('many', 184),
#  ('consequence', 183),
#  ('adverse', 182),
#  ('degree', 181),
#  ('mediator', 180),
#  ('contributing', 179),
#  ('individual', 178),
#  ('identify', 177),
#  ('association', 176),
#  ('viewed', 175),
#  ('focus', 174),
#  ('context', 173),
#  ('given', 172),
#  ('attention', 171),
#  ('victimization', 170),
#  ('exposure', 169),
#  ('support', 168),
#  ('lack', 167),
#  ('drug', 166),
#  ('mental', 165),
#  ('poor', 164),
#  ('similar', 163),
#  ('supervision', 162),
#  ('parental', 161),
#  ('parent', 160),
#  ('conflict', 159),
#  ('use', 158),
#  ('male', 157),
#  ('these', 156),
#  ('development', 155),
#  ('pattern', 154),
#  ('behavior', 153),
#  ('rate', 152),
#  ('high', 151),
#  ('le', 150),
#  ('delinquency', 149),
#  ('general', 148),
#  ('known', 147),
#  ('much', 146),
#  ('site', 145),
#  ('potential', 144),
#  ('determine', 143),
#  ('first', 142),
#  ('must', 141),
#  ('reduce', 140),
#  ('ed', 139),
#  ('columbia', 138),
#  ('district', 137),
#  ('every', 136),
#  ('for', 135),
#  ('number', 134),
#  ('suicide', 133),
#  ('include', 132),
#  ('10', 131),
#  ('death', 130),
#  ('cause', 129),
#  ('leading', 128),
#  ('state', 127),
#  ('united', 126),
#  ('true', 125),
#  ('especially', 124),
#  ('this', 123),
#  ('child', 122),
#  ('role', 121),
#  ('come', 120),
#  ('however', 119),
#  ('condition', 118),
#  ('infection', 117),
#  ('childhood', 116),
#  ('impact', 115),
#  ('reduced', 114),
#  ('public', 113),
#  ('improved', 112),
#  ('assessment', 111),
#  ('clinical', 110),
#  ('future', 109),
#  ('highrisk', 108),
#  ('common', 107),
#  ('fighting', 106),
#  ...]

# %%
#tfidf using gensim package
tfidf = gensim.models.tfidfmodel.TfidfModel(doc_term_matrix, id2word = dictionary)
corpus_tfidf = tfidf[doc_term_matrix]
word_score = {dictionary.get(id): value for doc in corpus_tfidf for id, value in doc}
sorted_word_score = sorted(word_score.items(), key=operator.itemgetter(1),reverse=True)
sorted_word_score
# Out:
# [('10', 1.0),
#  ('address', 1.0),
#  ('32', 1.0),
#  ('11', 1.0),
#  ('minnesota', 1.0),
#  ('7', 1.0),
#  ('6', 1.0),
#  ('educ', 0.8838954499422123),
#  ('received', 0.8776556790056448),
#  ('stress', 0.8675894586585865),
#  ('low', 0.7837963127721629),
#  ('unfortunately', 0.7591064951827186),
#  ('them', 0.7571788657915562),
#  ('2009', 0.7539076550002983),
#  ('lansing', 0.7148724499537761),
#  ('distinct', 0.7144493013197016),
#  ('degree', 0.6890778578365464),
#  ('episode', 0.6707643767239545),
#  ('tend', 0.6662376711322004),
#  ('classroom', 0.652405113327182),
#  ('pathway', 0.6522289505811617),
#  ('multidimensional', 0.6518984475280244),
#  ('duty', 0.6441516263528149),
#  ('involvement', 0.6396724947999675),
#  ('texas', 0.6202136500612716),
#  ('membership', 0.6187044462441232),
#  ('described', 0.6138971379254753),
#  ('r', 0.6111870878688889),
#  ('majority', 0.6072207324408523),
#  ('considered', 0.6037040674065984),
#  ('2011', 0.6024840366240158),
#  ('trajectory', 0.5990412804105867),
#  ('we', 0.5983087230258023),
#  ('prevalent', 0.5976289650781402),
#  ('consent', 0.5937932214562681),
#  ('provided', 0.5914345124478435),
#  ('representative', 0.5857144535680503),
#  ('matched', 0.5837934185746583),
#  ('subtypes', 0.5833922007156599),
#  ('commonly', 0.582766147628737),
#  ('life', 0.5811793180684022),
#  ('determine', 0.5784110951774),
#  ('collected', 0.5738768396648654),
#  ('event', 0.5736710641499054),
#  ('race', 0.5656375632241788),
#  ('true', 0.5640706678122497),
#  ('nonaggressive', 0.5624038447703125),
#  ('baumeister', 0.5592188775203146),
#  ('hospitalized', 0.5542899133648334),
#  ('right', 0.5511875493720798),
#  ('1993', 0.5490713300661119),
#  ('appear', 0.5487596356464775),
#  ('exist', 0.5452584879487387),
#  ('larger', 0.5447924722327638),
#  ('versus', 0.5444674740850435),
#  ('stop', 0.5441014914489849),
#  ('inform', 0.5433326073318279),
#  ('others', 0.5390495661381737),
#  ('bias', 0.5376977231407758),
#  ('recognition', 0.5374100896011107),
#  ('enrolled', 0.5367261674436465),
#  ('interest', 0.535070128243057),
#  ('course', 0.5350531625669729),
#  ('understood', 0.5340424767204475),
#  ('hbsc', 0.5340110037293818),
#  ('history', 0.5322025918909453),
#  ('implication', 0.5309727251815796),
#  ('not', 0.5308018951913914),
#  ('resource', 0.5306404514927879),
#  ('north', 0.5303422048081603),
#  ('shot', 0.5295152447147242),
#  ('biological', 0.5278749147972344),
#  ('quickly', 0.5271768355648278),
#  ('shooting', 0.5256799862171053),
#  ('going', 0.5256000635458528),
#  ('seattle', 0.5250641118387329),
#  ('female', 0.524066021770826),
#  ('impaired', 0.5214546667227595),
#  ('initially', 0.520546281477105),
#  ('crosssectional', 0.5182161955706238),
#  ('poor', 0.5178153562910868),
#  ('describe', 0.5172285496768739),
#  ('suicide', 0.5168698520973437),
#  ('tendency', 0.5159302811476626),
#  ('emphasis', 0.514231047315621),
#  ('effectively', 0.5128672429074239),
#  ('focusing', 0.5125743411625961),
#  ('enrollment', 0.5103981090764151),
#  ('discipline', 0.5103905846534922),
#  ('overall', 0.5102917169715296),
#  ('clear', 0.5088713935869066),
#  ('due', 0.5086328436211132),
#  ('demonstrated', 0.5074506252354392),
#  ('0', 0.5063097574502466),
#  ('see', 0.5061059357620115),
#  ('moreover', 0.5057500025974133),
#  ('prepubertal', 0.5025748385733001),
#  ('crisishttpwwwapaorgedschoolscpseactivitiesviolenceagainstaspxêgoogle',
#   0.5002482363331955),
#  ('an', 0.49645511945144766),
#  ('especially', 0.4944483229020892),
#  ('criterion', 0.4924508553744311),
#  ('university', 0.49068011340177464),
#  ('turn', 0.49018314041879407),
#  ('practice', 0.48818171472373634),
#  ('influence', 0.48780195364622597),
#  ('consider', 0.4869204046872604),
#  ('silent', 0.4866695887019065),
#  ('intervene', 0.48579276163108026),
#  ('claim', 0.4854847137019235),
#  ('point', 0.4846198999187906),
#  ('seeking', 0.4844295887976784),
#  ('belief', 0.4834538531425618),
#  ('per', 0.48129903084827536),
#  ('held', 0.48105880984890037),
#  ('reduction', 0.4805844756353021),
#  ('pattern', 0.48037831574994133),
#  ('insight', 0.47799221710986806),
#  ('instrumental', 0.4758546844605851),
#  ('correlated', 0.4750820339003776),
#  ('education', 0.4747356229880025),
#  ('done', 0.47462297135315934),
#  ('list', 0.4731883690863061),
#  ('dynamic', 0.4731883690863061),
#  ('gun', 0.4729989197337016),
#  ('plan', 0.4725395837168012),
#  ('caused', 0.47194016661542465),
#  ('benefit', 0.47029109546895764),
#  ('internal', 0.47008617353082677),
#  ('city', 0.46865163104528806),
#  ('attack', 0.4684507046277648),
#  ('symptom', 0.468151975013962),
#  ('warning', 0.46779533893984726),
#  ('parenting', 0.4669424921053484),
#  ('lead', 0.46537820431753407),
#  ('limitation', 0.465355088541603),
#  ('assist', 0.46510113373663103),
#  ('example', 0.4650566238322728),
#  ('ideation', 0.462286546262711),
#  ('with', 0.46160686431886067),
#  ('various', 0.46160686431886067),
#  ('implementation', 0.46160686431886067),
#  ('believe', 0.4601050626726505),
#  ('men', 0.45993104150449704),
#  ('excluded', 0.4588532893478026),
#  ('regard', 0.4587297041380858),
#  ('occurs', 0.4587297041380858),
#  ('article', 0.45725547803263544),
#  ('america', 0.4572268669664575),
#  ('deficit', 0.4560913256480371),
#  ('therefore', 0.45518561278476083),
#  ('term', 0.452869897386546),
#  ('suggestion', 0.4527252751478313),
#  ('14', 0.45261403021949703),
#  ('face', 0.45259481649941424),
#  ('either', 0.4521464271410676),
#  ('official', 0.45142639648246813),
#  ('develop', 0.4512371326580187),
#  ('therapist', 0.45068289522936816),
#  ('conduct', 0.4501561391828206),
#  ('mediates', 0.449444411328291),
#  ('providing', 0.4493812150789287),
#  ('directed', 0.4476416642165902),
#  ('police', 0.44725776274053586),
#  ('logistic', 0.4471159661864903),
#  ('26', 0.44628586436016293),
#  ('selection', 0.44577230790214595),
#  ('personal', 0.44496148836360305),
#  ('disease', 0.4432940847982276),
#  ('soriano', 0.44302183345735124),
#  ('instance', 0.4419516893066779),
#  ('categorized', 0.4419236655315994),
#  ('combination', 0.4417084648530717),
#  ('interact', 0.441238249326096),
#  ('making', 0.4409370094351116),
#  ('predictive', 0.44090207816507593),
#  ('discussed', 0.44087069540307156),
#  ('best', 0.44073947699752847),
#  ('most', 0.43934450274845044),
#  ('vary', 0.43931112153995616),
#  ('fully', 0.43741043177008143),
#  ('feeling', 0.43719018088540296),
#  ('psychosocial', 0.436770788771331),
#  ('think', 0.43670293746996625),
#  ('hoover', 0.43670293746996625),
#  ('harmful', 0.43670293746996625),
#  ('clinical', 0.4365768303497991),
#  ('from', 0.435789783423171),
#  ('frequently', 0.43549189557858925),
#  ('primarily', 0.43531212893430604),
#  ('progress', 0.4343931528649626),
#  ('experienced', 0.4341238354904887),
#  ('approved', 0.43352744823441625),
#  ('88', 0.43342024214775876),
#  ('prevalence', 0.4332325006821579),
#  ('criminal', 0.4329756507917666),
#  ('trauma', 0.4312613903531029),
#  ('conclusion', 0.4309796725971169),
#  ('reason', 0.43071077460422663),
#  ('80', 0.42955140084649973),
#  ('issue', 0.42902744082593686),
#  ('value', 0.428455568485501),
#  ('yet', 0.428455568485501),
#  ('validity', 0.42775347080669907),
#  ('total', 0.4274048749808537),
#  ('participate', 0.42723080108919753),
#  ('knowledge', 0.42702697820801816),
#  ('effort', 0.4267370729468749),
#  ('made', 0.42597785248645964),
#  ('manual', 0.42557114490952547),
#  ('respond', 0.42551217921317636),
#  ('correlation', 0.4246879182878749),
#  ('carefully', 0.42313869051412406),
#  ('many', 0.423118988415541),
#  ('vulnerable', 0.4223198947608687),
#  ('selected', 0.42231199603383074),
#  ('request', 0.4221539165686778),
#  ('characterized', 0.42155685365127477),
#  ('selfreported', 0.4207632052059805),
#  ('based', 0.42071334377564606),
#  ('situation', 0.420280976443786),
#  ('last', 0.4189794803331464),
#  ('item', 0.4185603147625226),
#  ('training', 0.4180459652056975),
#  ('five', 0.4174718551145781),
#  ('focused', 0.41685484329246814),
#  ('regression', 0.4151932987343618),
#  ('activity', 0.4144247394792811),
#  ('impairment', 0.41387781400389384),
#  ('alternative', 0.41340488234377276),
#  ('questionnaire', 0.41210510068931333),
#  ('sampled', 0.41192020067193896),
#  ('72', 0.41111539364688826),
#  ('participant', 0.4098813762810863),
#  ('culture', 0.40983577622761314),
#  ('following', 0.40939392055475227),
#  ('16', 0.40919826215910987),
#  ('protocol', 0.4086407234587094),
#  ('anger', 0.4068600772305375),
#  ('along', 0.40663583200325154),
#  ('commit', 0.4063024542011401),
#  ('morbidity', 0.4062281670188369),
#  ('extracurricular', 0.40590061375477016),
#  ('homicide', 0.4051374867136213),
#  ('relevant', 0.40479263328876697),
#  ('effect', 0.40469575564578086),
#  ('multivariate', 0.4045906116835716),
#  ('incidence', 0.40373193807526),
#  ('standardized', 0.40370140320067865),
#  ('admitted', 0.4028495801334273),
#  ('institutional', 0.402445023147599),
#  ('detail', 0.4015984085559389),
#  ('committing', 0.4006812948733116),
#  ('inconsistent', 0.400013831544452),
#  ('1996', 0.4000133176546819),
#  ('cannot', 0.39952027494829273),
#  ('order', 0.3994758902250161),
#  ('regular', 0.39930831378861215),
#  ('carrying', 0.39930831378861215),
#  ('disruptive', 0.3991793012247909),
#  ('monitoring', 0.39877321127680454),
#  ('canadian', 0.398610640482135),
#  ('girl', 0.39739300285376905),
#  ('crucial', 0.3972196893746779),
#  ('eligible', 0.39688951716931553),
#  ('improved', 0.39680781522994757),
#  ('communication', 0.39680781522994757),
#  ('perpetration', 0.3952925692280055),
#  ('still', 0.39484164263389465),
#  ('craig', 0.3941853352260475),
#  ('strong', 0.3940703776517641),
#  ('link', 0.3940703776517641),
#  ('reach', 0.39385090500729786),
#  ('arousal', 0.39306854272907593),
#  ('change', 0.3927414794185903),
#  ('viewed', 0.39245135623263006),
#  ('limit', 0.39245135623263006),
#  ('without', 0.3919493229740252),
#  ('setting', 0.39153190932324416),
#  ('socially', 0.3906829693231248),
#  ('federal', 0.3905483002569589),
#  ('difficulty', 0.3901190801801553),
#  ('highly', 0.3898560433681179),
#  ('cortisol', 0.38976887857951187),
#  ('indicated', 0.3894589785032564),
#  ('17', 0.3888084745699791),
#  ('active', 0.3884723151480945),
#  ('known', 0.38782067686160276),
#  ('like', 0.3870942740477007),
#  ('search', 0.3870942740477007),
#  ('possibility', 0.38709291851110184),
#  ('provides', 0.38650168962826853),
#  ('attention', 0.38626280141201325),
#  ('toward', 0.38589092620792087),
#  ('global', 0.38575392529231195),
#  ('both', 0.3855290976259947),
#  ('effectiveness', 0.3853803394729179),
#  ('clinically', 0.384969855124276),
#  ('our', 0.38483662075796565),
#  ('relation', 0.3846002069614457),
#  ('numerous', 0.38384369268991064),
#  ('include', 0.3836804474277856),
#  ('adverse', 0.3836323302921813),
#  ('management', 0.38345645735980927),
#  ('driver', 0.3831620764329222),
#  ('potentially', 0.38247701615125207),
#  ('incident', 0.38234970240148103),
#  ('other', 0.38229076381896754),
#  ('world', 0.3822597321075963),
#  ('appears', 0.38197819581766745),
#  ('referral', 0.3818084523062556),
#  ('therapy', 0.38122008224572523),
#  ('vulnerability', 0.38083328625127977),
#  ('purpose', 0.38052684815476734),
#  ('line', 0.3803707617730003),
#  ('t', 0.3800602174135628),
#  ('investigation', 0.3784000233419502),
#  ('nezu', 0.37826319030861294),
#  ('serve', 0.3780504985089113),
#  ('environmental', 0.3779311303119274),
#  ('hour', 0.37744695760235125),
#  ('usually', 0.37730747401059356),
#  ('decrease', 0.37630752719994537),
#  ('death', 0.37591669332337707),
#  ('basis', 0.37572216751055504),
#  ('strongly', 0.3750643655428907),
#  ('rather', 0.3747736428979655),
#  ('studentsõ', 0.3742627905934402),
#  ('people', 0.37422465849590575),
#  ('take', 0.37360538322465264),
#  ('determined', 0.37339281557782794),
#  ('physiological', 0.3731569227395645),
#  ('work', 0.37306326266349665),
#  ('demonstrate', 0.3716670514687704),
#  ('experience', 0.3716271352349543),
#  ('controlling', 0.3715570518535816),
#  ('cost', 0.3709756824997012),
#  ('regarding', 0.37049688673707337),
#  ('illness', 0.3698817813322911),
#  ('brought', 0.36909920062680757),
#  ('variable', 0.3690225298643859),
#  ('success', 0.3689220889046458),
#  ('testosterone', 0.368893745264829),
#  ('initial', 0.36871968881145517),
#  ('scholar', 0.36775879805178224),
#  ('within', 0.367488626624398),
#  ('survey', 0.36743357650745756),
#  ('building', 0.3672016056659764),
#  ('earlier', 0.36710201252818014),
#  ('agent', 0.3665996852352168),
#  ('used', 0.36568580911207),
#  ('mechanism', 0.36560194888586045),
#  ('false', 0.3654319866286699),
#  ('person', 0.3653968989882834),
#  ('mediator', 0.3651266552420027),
#  ('structure', 0.3649515217555558),
#  ('examined', 0.36447229185985863),
#  ('whereas', 0.36354838779237464),
#  ('surveillance', 0.36337460905742847),
#  ('suggests', 0.3629540852092201),
#  ('le', 0.362839972258823),
#  ('behaviour', 0.3626203249257233),
#  ('four', 0.3621581569370833),
#  ('perspective', 0.361976619892553),
#  ('subsequent', 0.3613838417440304),
#  ('motivation', 0.3607734963850482),
#  ('obtain', 0.3604252909434699),
#  ('month', 0.3603737957270396),
#  ('remain', 0.3599534673552997),
#  ('particularly', 0.3599433980173393),
#  ('ensuring', 0.3590026178432486),
#  ('common', 0.35845963573245737),
#  ('legal', 0.35820383405127504),
#  ('percent', 0.35771203478173347),
#  ('thus', 0.35728184512996725),
#  ('crossnational', 0.3572153522583461),
#  ('perpetrator', 0.35700925116168436),
#  ('established', 0.3566547889884429),
#  ('while', 0.35661721155316645),
#  ('power', 0.35554216185623894),
#  ('diagnostic', 0.3553977860839112),
#  ('advocate', 0.35535962075753696),
#  ('street', 0.354898437884817),
#  ('almost', 0.3546852427576744),
#  ('oak', 0.3546557640806722),
#  ('more', 0.35459321082418604),
#  ('place', 0.3544779062366245),
#  ('better', 0.3544779062366245),
#  ('difference', 0.3541247671644445),
#  ('intentional', 0.35411652805550575),
#  ('integrated', 0.3538714519819468),
#  ('nonetheless', 0.3536608111038316),
#  ('estimate', 0.35270080510070373),
#  ('reduced', 0.3524996636641026),
#  ('add', 0.3524184909580972),
#  ('least', 0.3516960262186988),
#  ('path', 0.35139739791314917),
#  ('according', 0.35065465397194256),
#  ('rate', 0.3497060226219648),
#  ('objective', 0.3493734453335983),
#  ('much', 0.3493301375840855),
#  ('casecontrol', 0.34862266427297145),
#  ('possible', 0.3482971123190433),
#  ('model', 0.3482522833895945),
#  ('harsh', 0.348152821962491),
#  ('psychological', 0.347579886909338),
#  ('literature', 0.34724548956736995),
#  ('psychiatric', 0.34724548956736995),
#  ('they', 0.3471225708015919),
#  ('randomized', 0.34663449570461613),
#  ('profile', 0.34610391990882217),
#  ('anxiety', 0.34589138973298256),
#  ('delinquency', 0.3453840753618033),
#  ('1995', 0.3453502101570419),
#  ('researcher', 0.34477345410441235),
#  ('18', 0.3443631752483129),
#  ('involves', 0.3441275110693884),
#  ('abstract', 0.34383344149977224),
#  ('requires', 0.34383344149977224),
#  ('onset', 0.343648932840549),
#  ('consideration', 0.34357862924423865),
#  ('complex', 0.34316109674463385),
#  ('estimated', 0.34273695521708974),
#  ('reducing', 0.3425822172594998),
#  ('weaponcarrying', 0.3425150212206683),
#  ('cultural', 0.3422265393845545),
#  ('200', 0.3415488456707923),
#  ('ability', 0.3414775805032645),
#  ('staff', 0.3413296106565152),
#  ('go', 0.3411322468608256),
#  ('guide', 0.34106283885724004),
#  ('simply', 0.3408711091857473),
#  ('indicator', 0.3405134177202301),
#  ('expected', 0.3405134177202301),
#  ('bullying', 0.34028485355037225),
#  ('prevention', 0.34026153458645936),
#  ('42', 0.33993541707686087),
#  ('psychologist', 0.33950230053444896),
#  ('90', 0.33946294854270587),
#  ('reactive', 0.33871007782658974),
#  ('community', 0.3381363419282257),
#  ('developing', 0.33809404475467053),
#  ('key', 0.33759303129882307),
#  ('preventing', 0.33732328593030414),
#  ('harm', 0.33720321339412124),
#  ('leave', 0.3363939264111202),
#  ('subject', 0.3361291488538017),
#  ('infection', 0.3360104123862809),
#  ('selfreport', 0.3354314663269031),
#  ('canada', 0.33509587529282897),
#  ('empirical', 0.3348527319971153),
#  ('offer', 0.33447340383770985),
#  ('someone', 0.3343958356709837),
#  ('personality', 0.3343229780427684),
#  ('supervision', 0.3340317583052319),
#  ('nutrition', 0.3330521751163559),
#  ('coefficient', 0.33298230357306646),
#  ('part', 0.3328843618489474),
#  ('focus', 0.33287018995964984),
#  ('economic', 0.33280782681303006),
#  ('attempt', 0.33274813981514617),
#  ('osofsky', 0.332380978749754),
#  ('dõzurilla', 0.33209476627872),
#  ('administrator', 0.3320853094263355),
#  ('significantly', 0.3309139165732582),
#  ('day', 0.3307431200459252),
#  ('institute', 0.3307431200459252),
#  ('includes', 0.33057720198955187),
#  ('kd', 0.33057720198955187),
#  ('attitude', 0.3305469949574982),
#  ('because', 0.3302972363101672),
#  ('fear', 0.33003325816890844),
#  ('detailed', 0.32997228230703624),
#  ('lifetime', 0.32992813907057394),
#  ('increase', 0.3295353460166411),
#  ('got', 0.32937532029908995),
#  ('he', 0.32937532029908995),
#  ('kid', 0.32937532029908995),
#  ('additional', 0.3293475875354322),
#  ('uninjured', 0.3292422180638498),
#  ('on', 0.3288841970384034),
#  ('specific', 0.3288594025989775),
#  ('highlight', 0.3288561416387418),
#  ('physically', 0.3287364487240505),
#  ('selfesteem', 0.32860743034472495),
#  ('major', 0.32858263017224915),
#  ('show', 0.32836675701378304),
#  ('mood', 0.32769058601447615),
#  ('noted', 0.3270724003518388),
#  ('proactive', 0.3267736184542814),
#  ('help', 0.32670572436196016),
#  ('campus', 0.3260582609876149),
#  ('minority', 0.3259698268282455),
#  ('combined', 0.3259000663050344),
#  ('emotional', 0.32564389319914067),
#  ('evaluating', 0.3255515551830831),
#  ('report', 0.32520803455385805),
#  ('stability', 0.32518413969611526),
#  ('heightened', 0.3250969986708849),
#  ('oliver', 0.32494182149151923),
#  ('control', 0.3247677606070826),
#  ('gang', 0.3245988353399011),
#  ('new', 0.324403888114116),
#  ('suggest', 0.32417004488305634),
#  ('interviewing', 0.3241440862236847),
#  ('cohort', 0.3241440862236847),
#  ('firearm', 0.32406937563466137),
#  ('bangladesh', 0.3240118671246908),
#  ('al', 0.3239629145977632),
#  ('across', 0.3235575058660805),
#  ('diverse', 0.32335519446900857),
#  ('respondent', 0.3229153679533775),
#  ('method', 0.3228985246788518),
#  ('smoking', 0.32283456049973913),
#  ('boy', 0.3226776000316554),
#  ('particular', 0.3223272445207903),
#  ('2000', 0.32195521455972714),
#  ('category', 0.3216225528377258),
#  ('indicates', 0.3215642199933173),
#  ('middle', 0.321381235391436),
#  ('partner', 0.3213572311084667),
#  ('recruited', 0.3205052566172185),
#  ('measured', 0.32029195794673015),
#  ('aq', 0.32029195794673015),
#  ('punishment', 0.3202355458724919),
#  ('mean', 0.3200636167282715),
#  ('record', 0.3200231107069628),
#  ('cluster', 0.3199297300207236),
#  ('contributing', 0.3199156953489128),
#  ('long', 0.319850566696601),
#  ('retaliate', 0.3195881190990568),
#  ('occurred', 0.319372515160893),
#  ('nationally', 0.31894615157923495),
#  ('observed', 0.3188329554627551),
#  ('functioning', 0.3187956779363282),
#  ('needed', 0.3183631606650352),
#  ('strength', 0.31803222217981497),
#  ('reduce', 0.31744165561475074),
#  ('longitudinal', 0.3168583082998583),
#  ('ra', 0.3164857277079365),
#  ('et', 0.3161950323258036),
#  ('eisenbraun', 0.3159488257568105),
#  ('evaluate', 0.3154250472969299),
#  ('increased', 0.31540720338239114),
#  ('orientation', 0.31455621587279686),
#  ('prospective', 0.3140613586398828),
#  ('assessing', 0.31381104184672737),
#  ('assistant', 0.31309138716386054),
#  ('immediately', 0.31309138716386054),
#  ('though', 0.31297242193528596),
#  ('carry', 0.312929163640635),
#  ('approach', 0.31284029034582383),
#  ('interaction', 0.3127005263731894),
#  ('adolescence', 0.31245279977354495),
#  ('andor', 0.31222395476483655),
#  ('required', 0.3116999767310862),
#  ('presented', 0.3116345401139922),
#  ('define', 0.3114859931735042),
#  ('reflect', 0.311182683553036),
#  ('review', 0.31078756460678925),
#  ('ass', 0.31054896344803634),
#  ('improvement', 0.3104188410856458),
#  ('obtained', 0.30955017145508923),
#  ('linked', 0.309225484548241),
#  ('examine', 0.30907667846028325),
#  ('systematic', 0.3090488278494317),
#  ('459ð469', 0.30904639938865874),
#  ('index', 0.308350660776017),
#  ('witnessing', 0.30829659716654434),
#  ('frequency', 0.3082463976921011),
#  ('next', 0.3082201542681841),
#  ('cbt', 0.3081593934014931),
#  ('problemsolving', 0.30778391442060327),
#  ('affect', 0.3076804775438997),
#  ('living', 0.30753339532674073),
#  ('verbal', 0.3074212752857925),
#  ('presence', 0.3072936156290884),
#  ('limited', 0.30724680574655444),
#  ('average', 0.3072456709491301),
#  ('tool', 0.30719171164940834),
#  ('predictor', 0.3069980897331981),
#  ('lower', 0.3067916794318199),
#  ('furlong', 0.30666978182361193),
#  ('ivr', 0.30636063464283875),
#  ('addition', 0.3063398525792742),
#  ('treated', 0.30608709673402396),
#  ('relatively', 0.30595728952333734),
#  ('demographic', 0.3059144469306912),
#  ('lack', 0.30571562456665446),
#  ('reporting', 0.3056782098052848),
#  ('derived', 0.30532547394758114),
#  ('behavioral', 0.3048598296407988),
#  ('question', 0.3048101305617174),
#  ('private', 0.30448125360077355),
#  ('1992', 0.30440442865285094),
#  ('relationship', 0.303764330992317),
#  ('rural', 0.3036479398130697),
#  ('another', 0.3035004893185476),
#  ('and', 0.3031989373135635),
#  ('2007', 0.30287196860254556),
#  ('perry', 0.30281949275055187),
#  ('authority', 0.3019012318520716),
#  ('chief', 0.301893390821392),
#  ('childhood', 0.30184735725970085),
#  ('tested', 0.3017970043909936),
#  ('minor', 0.3017494960951687),
#  ('compared', 0.30169265737941053),
#  ('shown', 0.30130021391573875),
#  ('highest', 0.3007389195008032),
#  ('procedure', 0.30045665093887486),
#  ('justice', 0.3002093720394616),
#  ('serotonin', 0.29990758642509424),
#  ('phone', 0.29976097110330546),
#  ('ratio', 0.299690295997752),
#  ('michigan', 0.29965783321601863),
#  ('approximately', 0.2996573913588968),
#  ('recruitment', 0.29815199488564004),
#  ('marker', 0.29813985941664556),
#  ('controlled', 0.29793525240698493),
#  ('way', 0.29760488675719626),
#  ('large', 0.2973764218769006),
#  ('extremely', 0.29729990848196386),
#  ('suburban', 0.2970142467098267),
#  ('home', 0.29681246118341503),
#  ('several', 0.2967505771798822),
#  ('i', 0.2963450069064641),
#  ('l', 0.29608784388988674),
#  ('coping', 0.29607514717511985),
#  ('there', 0.2954038487358822),
#  ('break', 0.2951962773371186),
#  ('attachment', 0.2948811933478193),
#  ('involving', 0.29393978837287515),
#  ('third', 0.29393978837287515),
#  ('statistical', 0.2935960395790994),
#  ('atrisk', 0.2934509761600268),
#  ('multiple', 0.2934509761600268),
#  ('performance', 0.29308916160316384),
#  ('explanation', 0.2924860621005753),
#  ('acceptable', 0.2924860621005753),
#  ('always', 0.2924860621005753),
#  ('instrument', 0.29169610035782995),
#  ('case', 0.2915979614653548),
#  ('13', 0.29117903882315294),
#  ('led', 0.29092151548329565),
#  ('human', 0.2908711504120298),
#  ('process', 0.29086091262882174),
#  ('problematic', 0.29086091262882174),
#  ('assaultrelated', 0.29080387136753294),
#  ('medication', 0.29079408431164094),
#  ('provide', 0.2906054871909237),
#  ('court', 0.2902707481125301),
#  ('form', 0.290244280043821),
#  ('elementary', 0.29023107728522024),
#  ('threat', 0.29007541488187416),
#  ('solution', 0.28971423507320637),
#  ('instead', 0.28950628598394834),
#  ('cigarette', 0.2893663637988584),
#  ('two', 0.289308701847968),
#  ('increasing', 0.28909850316039704),
#  ('african', 0.2890333785304962),
#  ('previous', 0.28836384309891033),
#  ('united', 0.28831641899894195),
#  ('professional', 0.2880760546643003),
#  ('socioeconomic', 0.2880760546643003),
#  ('threatened', 0.2878761511009097),
#  ('understand', 0.2878761511009097),
#  ('second', 0.2878340806365462),
#  ('information', 0.2877854485359902),
#  ('committed', 0.2877733170584776),
#  ('designed', 0.2875494542133565),
#  ('status', 0.2874014353222585),
#  ('efficacy', 0.2871105928349239),
#  ('relative', 0.28708995722699177),
#  ('academic', 0.28668614253061847),
#  ('cause', 0.28667550097433475),
#  ('difficult', 0.28667550097433475),
#  ('international', 0.2865089143706526),
#  ('recent', 0.2860381763708556),
#  ('standard', 0.285626721792777),
#  ('to', 0.28530935799525786),
#  ('component', 0.28471310455491666),
#  ('context', 0.28435878356283456),
#  ('primary', 0.28426038713291985),
#  ('assessment', 0.28385702611431507),
#  ('act', 0.28385702611431507),
#  ('offender', 0.28328318254970336),
#  ('cumulative', 0.283211539206058),
#  ('impact', 0.2822448620841345),
#  ('become', 0.28207325412255063),
#  ('appropriate', 0.28095844679336135),
#  ('able', 0.28036446910154433),
#  ('sexual', 0.27989362465536627),
#  ('conflict', 0.2797440435662722),
#  ('one', 0.279732622519099),
#  ('period', 0.27957828788117256),
#  ('imci', 0.2793154648058134),
#  ('national', 0.27918503295490127),
#  ('consistency', 0.27872338472369945),
#  ('country', 0.27862018091919266),
#  ('cycle', 0.2782504794670614),
#  ('longterm', 0.2782504794670614),
#  ('characteristic', 0.2781969207517027),
#  ('¤', 0.2781681297606093),
#  ('impulsivitycarelessness', 0.27811555207043687),
#  ('make', 0.27810684752620257),
#  ('support', 0.27803905716747684),
#  ('sampling', 0.27803503435099114),
#  ('solving', 0.27796942165172117),
#  ('implement', 0.27753304259855727),
#  ('current', 0.27750698778774285),
#  ('associationê2013american', 0.277343563640459),
#  ('associationê2013', 0.277343563640459),
#  ('distribution', 0.27724120932286517),
#  ('successfully', 0.27708021087927404),
#  ('understanding', 0.2769821060626478),
#  ('trial', 0.27696993634899775),
#  ('absence', 0.2768029010177743),
#  ('likely', 0.27678166232397755),
#  ('area', 0.27621358975501675),
#  ('prenatal', 0.2760231789158333),
#  ('action', 0.2753549619431522),
#  ('learn', 0.27484080522310195),
#  ('peer', 0.2746282024150405),
#  ('identify', 0.274053577879615),
#  ('edbased', 0.27388157017548176),
#  ('early', 0.273780605868561),
#  ('every', 0.2737479045524166),
#  ('percentage', 0.2737373482719199),
#  ('dependent', 0.27367688624863107),
#  ('must', 0.2730009300191093),
#  ('look', 0.27298310041476687),
#  ('predict', 0.2724880748856059),
#  ('given', 0.2723962361163819),
#  ('bus', 0.27213489947760755),
#  ('p', 0.27177561918850096),
#  ('greater', 0.2714815459858029),
#  ('completed', 0.2713810092439129),
#  ('exposed', 0.271235601041443),
#  ('even', 0.2708720247770471),
#  ('medium', 0.27064472975717585),
#  ('access', 0.27047851704075476),
#  ('identifying', 0.2701345323997088),
#  ('fighting', 0.2701315587763296),
#  ('conducted', 0.26980232356859746),
#  ('sustained', 0.2695991548622418),
#  ('c', 0.2695991548622418),
#  ('b', 0.2695991548622418),
#  ('potential', 0.2694618808987658),
#  ('interpersonal', 0.2694433707822465),
#  ('direct', 0.2693306408937885),
#  ('design', 0.26932284637705545),
#  ('of', 0.26928046210927703),
#  ('intervention', 0.26927906705536064),
#  ('workplace', 0.269144882098379),
#  ('arrest', 0.2689329446975817),
#  ('size', 0.2686174283951538),
#  ('stratified', 0.2683499704277792),
#  ('college', 0.26833298125664995),
#  ('affective', 0.2682959291744588),
#  ('seen', 0.26824388603392896),
#  ('urban', 0.26824388603392896),
#  ('this', 0.26818178762965084),
#  ('might', 0.2681572676902813),
#  ('style', 0.2675326547632285),
#  ('assessed', 0.2670710920718434),
#  ('certain', 0.266711707837117),
#  ('occurrence', 0.2661620841216839),
#  ('leading', 0.2658126678057682),
#  ('program', 0.2654174090282794),
#  ('comorbid', 0.26531000926206105),
#  ('cited', 0.2652371576283456),
#  ('figure', 0.26505306781072874),
#  ('developed', 0.26481559606218935),
#  ('above', 0.26465036607168535),
#  ('gender', 0.2640951200446877),
#  ('mayer', 0.2638712450674297),
#  ('leone', 0.2638712450674297),
#  ('random', 0.2637721625476538),
#  ('state', 0.2637092063811576),
#  ('in', 0.26359242629047464),
#  ('showed', 0.26305765826694283),
#  ('view', 0.26278093391047735),
#  ('finding', 0.262294402536195),
#  ('emergency', 0.26220680668233176),
#  ('male', 0.262033010885413),
#  ('comparison', 0.2619155597091388),
#  ('depression', 0.26153152355666376),
#  ('aged', 0.26102521757233715),
#  ('audiotape', 0.26056492211462007),
#  ('likelihood', 0.2604872411464185),
#  ('step', 0.26034733173815133),
#  ('extensive', 0.25995246052005055),
#  ('studied', 0.2586532276481345),
#  ('little', 0.25803760820352545),
#  ('hostility', 0.25744880089521816),
#  ('fact', 0.25724538851602624),
#  ('indicate', 0.25722880568078504),
#  ('mortality', 0.25709520609253655),
#  ('similar', 0.2565194260913574),
#  ('brockenbrough', 0.25593934312981004),
#  ('present', 0.2557191222122665),
#  ('ineffective', 0.25566334619070136),
#  ('would', 0.25552759398513725),
#  ('discussion', 0.2554870900589626),
#  ('play', 0.25501011166706183),
#  ('heaviside', 0.25501011166706183),
#  ('chronic', 0.2541227646264109),
#  ('mediating', 0.2537528889322517),
#  ('however', 0.2535786559524067),
#  ('american', 0.2534394881531326),
#  ('retaliation', 0.25328304005473257),
#  ('despite', 0.25328304005473257),
#  ('attrition', 0.25328304005473257),
#  ('followed', 0.25314144732097116),
#  ('knife', 0.25096457583101783),
#  ('survival', 0.25096457583101783),
#  ('negative', 0.2505578993254053),
#  ('taken', 0.25044055358252787),
#  ('grade', 0.25027581481518035),
#  ('clinician', 0.2502555896682213),
#  ('amount', 0.24943899262681926),
#  ('disciplinary', 0.24872366657162617),
#  ('later', 0.24859351871522475),
#  ('19', 0.2484216260172857),
#  ('educator', 0.2484001343773469),
#  ('highrisk', 0.248350687370176),
#  ('abuse', 0.24792841294126397),
#  ('attempted', 0.24770122326435998),
#  ('complete', 0.24770122326435998),
#  ('available', 0.2474738947946579),
#  ('future', 0.24706907735231826),
#  ('assaulted', 0.24673658927062922),
#  ('all', 0.246312664760653),
#  ('principal', 0.24622313088157674),
#  ('screening', 0.24610724140656337),
#  ('development', 0.24556551418004857),
#  ('severity', 0.24445545682643866),
#  ('u', 0.24394018909365744),
#  ('statistic', 0.2435951364745058),
#  ('cognitive', 0.24356800208345908),
#  ('victim', 0.2434594523650725),
#  ('remained', 0.24342888840192067),
#  ('get', 0.24315814789099865),
#  ('preventive', 0.24256329629396542),
#  ('small', 0.24219337153665266),
#  ('prevent', 0.24219337153665266),
#  ('related', 0.24206766141823333),
#  ('odds', 0.2419584871200713),
#  ('presenting', 0.2408337168524832),
#  ('service', 0.2406346281688436),
#  ('s', 0.2406346281688436),
#  ('utilization', 0.2401509602285001),
#  ('intent', 0.23962346145117058),
#  ('young', 0.23940253824373148),
#  ('neighborhood', 0.23918615657512818),
#  ('table', 0.2389339377227697),
#  ('site', 0.2387432794608702),
#  ('enforcement', 0.2386390580680602),
#  ('educational', 0.2386390580680602),
#  ('behavior', 0.23832349281864026),
#  ('identification', 0.23820981717801198),
#  ('finally', 0.23820981717801198),
#  ('provider', 0.2375295309737769),
#  ('juvenile', 0.2375295309737769),
#  ('importance', 0.23748036959532387),
#  ('hyman', 0.23740979096708836),
#  ('perone', 0.23740979096708836),
#  ('50', 0.23697864827178747),
#  ('12', 0.23656853429370592),
#  ('hypothesis', 0.2365579071123594),
#  ('could', 0.23641496321074593),
#  ('15', 0.23639801415173814),
#  ('24', 0.23639801415173814),
#  ('20', 0.23639801415173814),
#  ('studer', 0.23541637489944564),
#  ('dwyer', 0.23541637489944564),
#  ('sensitivity', 0.23539834445652322),
#  ('three', 0.2353607106348755),
#  ('if', 0.23512872112237176),
#  ('code', 0.2344804215518923),
#  ('source', 0.23422958209773895),
#  ('columbia', 0.2341555064630901),
#  ('higher', 0.23354640600383492),
#  ('severe', 0.23350113680736176),
#  ('note', 0.23349837686421573),
#  ('single', 0.23335357068795762),
#  ('since', 0.2331008450593936),
#  ('security', 0.232666586305356),
#  ('confidence', 0.23257922100098985),
#  ('system', 0.2318327299504896),
#  ('when', 0.2314187484392875),
#  ('organization', 0.23022046523200218),
#  ('evaluation', 0.22914541925421186),
#  ('defined', 0.22837583576815657),
#  ('parent', 0.2282017873695793),
#  ('department', 0.22670661357851724),
#  ('well', 0.226672265401776),
#  ('come', 0.2262352472090995),
#  ('challenge', 0.22615460436699447),
#  ('solve', 0.22615460436699447),
#  ('discharge', 0.22615261564860667),
#  ('these', 0.22604853642946623),
#  ('substance', 0.22598145687507534),
#  ('statute', 0.22574103858270783),
#  ('week', 0.22507061326247052),
#  ('awareness', 0.22469060753946435),
#  ('team', 0.22469060753946435),
#  ('clearly', 0.22445868742862762),
#  ('rule', 0.22445868742862762),
#  ('safe', 0.22425257211378355),
#  ('parental', 0.2240129543507199),
#  ('although', 0.22391020012523555),
#  ('assault', 0.22376116745398125),
#  ('board', 0.22310264640856037),
#  ('visit', 0.22262634416719504),
#  ('2001', 0.22204718305551718),
#  ('association', 0.22163596762403687),
#  ('serious', 0.22162391468346088),
#  ('score', 0.2209761991578341),
#  ('interval', 0.22077233006210337),
#  ('different', 0.22039943660921238),
#  ('scale', 0.2203610373797959),
#  ('center', 0.219999231520785),
#  ('year', 0.21994566394201173),
#  ('problem', 0.21973276347908716),
#  ('time', 0.2191135616290923),
#  ('perceived', 0.21816126660423837),
#  ('skiba', 0.2177115168633933),
#  ('technique', 0.21751900780955247),
#  ('feel', 0.21727703965557343),
#  ('violencerelated', 0.2170650151527254),
#  ('sv', 0.21703638788030846),
#  ('law', 0.21693691129141196),
#  ('aggressive', 0.21672486347322797),
#  ('represent', 0.21628022453557436),
#  ('public', 0.21576768612784536),
#  ('critical', 0.21576768612784536),
#  ('among', 0.2157506696092263),
#  ('range', 0.21534294796037393),
#  ('acute', 0.21460258665111026),
#  ('1999', 0.214413031081743),
#  ('peterson', 0.21421640779520895),
#  ('testretest', 0.21389533557847967),
#  ('often', 0.21385368697644547),
#  ('noninjured', 0.2138297786019034),
#  ('research', 0.21376994650272832),
#  ('ie', 0.21347979491936556),
#  ('spsir', 0.21317215673060635),
#  ('response', 0.21285470726964967),
#  ('dysfunctional', 0.21277350100831735),
#  ('pv', 0.21270022296240015),
#  ('identified', 0.2123821474326665),
#  ('group', 0.211947448377855),
#  ('condition', 0.21166970433001217),
#  ('typically', 0.211379310996941),
#  ('promote', 0.211379310996941),
#  ('younger', 0.21095474170891446),
#  ('also', 0.21073926180222827),
#  ('fight', 0.21061799912402748),
#  ('care', 0.21017612614130227),
#  ('outcome', 0.20985525728658713),
#  ('number', 0.209634541513628),
#  ('participated', 0.2094903699050815),
#  ('location', 0.20936193724737498),
#  ('suggested', 0.20902298260284874),
#  ('001', 0.20896627878080146),
#  ('assaultinjured', 0.20873332018038152),
#  ('general', 0.208438287363994),
#  ('reported', 0.20812910668904305),
#  ('unintentional', 0.20628639548244584),
#  ('population', 0.20584009092326844),
#  ('rational', 0.2055811849131949),
#  ('examining', 0.2055132765000026),
#  ('antisocial', 0.20505954798276996),
#  ('important', 0.20487124074306817),
#  ('misuse', 0.20458094106909283),
#  ('adolescent', 0.20438101041391227),
#  ('weapon', 0.20401184559052057),
#  ('directly', 0.20342729994034361),
#  ('respectively', 0.20329413591192333),
#  ('followup', 0.20302054446532525),
#  ('protective', 0.20260149509537928),
#  ('whether', 0.20214081623562),
#  ('disorder', 0.20198963820724747),
#  ('concern', 0.20176414544813462),
#  ('4', 0.20176414544813462),
#  ('goal', 0.20176414544813462),
#  ('teacher', 0.201139461931996),
#  ('avoidance', 0.20061247538346902),
#  ('violent', 0.20046110500403708),
#  ('schoolbased', 0.20017610617446668),
#  ('role', 0.1992599159329947),
#  ('involved', 0.19920800511564893),
#  ('interview', 0.19875940701116945),
#  ('ethnicity', 0.19855941532588336),
#  ('olweus', 0.19855941532588336),
#  ('bulach', 0.19855941532588336),
#  ('mental', 0.19821479354288657),
#  ('5', 0.19773310430462632),
#  ('personnel', 0.19768267287902358),
#  ('member', 0.19725238111022245),
#  ...]

# %%
#tfidf using sklearn package
tf = TfidfVectorizer(analyzer='word', ngram_range=(1,5), min_df = 7, stop_words = stop)
tfidf_matrix =  tf.fit_transform(texts)
feature_names = tf.get_feature_names() 
len(feature_names)
#feature_names
# Out:
# 1079

# %%
#sort term scores
dense = tfidf_matrix.todense()
sentences = dense[0].tolist()[0]
phrase_scores = [pair for pair in zip(range(0, len(sentences)), sentences) if pair[1] > 0]
#sorted(phrase_scores, key=lambda t: t[1] * -1)
# Out:
# [(569, 0.349048744487835),
#  (250, 0.3405919766274855),
#  (835, 0.3153315049578426),
#  (834, 0.3128163780710334),
#  (141, 0.3037066028827922),
#  (762, 0.2976915955908614),
#  (761, 0.2905195861958976),
#  (525, 0.2706352338457243),
#  (72, 0.2504072958656692),
#  (392, 0.2138901261898197),
#  (511, 0.21162561305466937),
#  (137, 0.1988846102725775),
#  (830, 0.18324219036426342)]

# %%
#Match term ID with term
sorted_phrase_scores = sorted(phrase_scores, key=lambda t: t[1] * -1)
for phrase, score in [(feature_names[word_id], score) for (word_id, score) in sorted_phrase_scores][:20]:
    print('{0: <20} {1}'.format(phrase, score))
# Out:
# risk protective factors 0.5127876891759959
# risk protective      0.5086976249610557
# assault injury       0.49388343578476157
# protective factors   0.48410191493730187
