# %% [markdown]
# ## Find important words in research articles about school violence

# %%
import pandas as pd
import nltk
import numpy as np
# %matplotlib inline  
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
import gensim
from gensim import corpora
from operator import itemgetter

# %%
#Take one txt file as an example
example_file = open('data/d1.txt')

# %%
import sys  

reload(sys)  
sys.setdefaultencoding('utf8')

# %%
#Parse by sentences
import nltk.data
tokenizer = nltk.data.load('tokenizers/punkt/english.pickle')
data = example_file.read()
docs = tokenizer.tokenize(data)

# %%
#Clean the input
stop = set(stopwords.words('english'))
stop.update(["this","these","many","may",'we','in','of','to','And','It',"It's","The",'the','abstract','background','them', '1','2','3','4','5','6','7','8','9'])
exclude = set(string.punctuation) 
lemma = WordNetLemmatizer()

def clean(doc):
    stop_free = " ".join([i.lower() for i in str(doc).split() if i not in stop])
    punc_free = ''.join(ch for ch in stop_free if ch not in exclude)
    normalized = " ".join(lemma.lemmatize(word) for word in punc_free.split())
    return normalized

# %%
#build dictionary and term matrix
doc_clean = [clean(doc).split() for doc in docs]
dictionary = corpora.Dictionary(doc_clean)
dictionary.filter_extremes(no_above=0.1)
doc_term_matrix = [dictionary.doc2bow(doc) for doc in doc_clean]

#Words in the dictionary sorted by the number of time it appeared in the doc
sorted_dict = sorted(dictionary.token2id.items(), key=lambda x: x[1], reverse = True)
sorted_dict
# Out:
# [(u'con', 141),
#  (u'2008', 140),
#  (u'time', 139),
#  (u'u', 138),
#  (u'without', 137),
#  (u'analysis', 136),
#  (u'alcohol', 135),
#  (u'response', 134),
#  (u'data', 133),
#  (u'included', 132),
#  (u'significant', 131),
#  (u'assignment', 130),
#  (u'higher', 129),
#  (u'intention', 128),
#  (u'finding', 127),
#  (u'connectedness', 126),
#  (u'5', 125),
#  (u'high', 124),
#  (u'1', 123),
#  (u'nonparticipant', 122),
#  (u'grant', 121),
#  (u'baseline', 120),
#  (u'participant', 119),
#  (u'education', 118),
#  (u'in', 117),
#  (u'sample', 116),
#  (u'evidence', 115),
#  (u'al', 114),
#  (u'measure', 113),
#  (u'nearest', 112),
#  (u'district\u2019s', 111),
#  (u'similar', 110),
#  (u'toward', 109),
#  (u'following', 108),
#  (u'9th', 107),
#  (u'three', 106),
#  (u'future', 105),
#  (u'value', 104),
#  (u'likely', 103),
#  (u'measured', 102),
#  (u'j', 101),
#  (u'whether', 100),
#  (u'16', 99),
#  (u'14', 98),
#  (u'12', 97),
#  (u'account', 96),
#  (u'10', 95),
#  (u'spillover', 94),
#  (u'extracurricular', 93),
#  (u'tested', 92),
#  (u'students\u2019', 91),
#  (u'followup', 90),
#  (u'national', 89),
#  (u'participated', 88),
#  (u'percentage', 87),
#  (u'6', 86),
#  (u'2', 85),
#  (u'indicate', 84),
#  (u'next', 83),
#  (u'two', 82),
#  (u'positive', 81),
#  (u'to', 80),
#  (u'district', 79),
#  (u'publication', 78),
#  (u'172\u2013178', 77),
#  (u'clustering', 76),
#  (u'size', 75),
#  (u'table', 74),
#  (u'one', 73),
#  (u'period', 72),
#  (u'within', 71),
#  (u'connection', 70),
#  (u'jamesburdumy', 69),
#  (u'among', 68),
#  (u'first', 67),
#  (u'unintentional', 66),
#  (u'consequence', 65),
#  (u'2007\u20132008', 64),
#  (u'survey', 63),
#  (u'conducted', 62),
#  (u'prior', 61),
#  (u'participating', 60),
#  (u'30', 59),
#  (u'adolescent', 58),
#  (u'outcome', 57),
#  (u'coveredactivity', 56),
#  (u'hypothesis', 55),
#  (u'reported', 54),
#  (u'however', 53),
#  (u'journal', 52),
#  (u's', 51),
#  (u'stance', 50),
#  (u'statistically', 49),
#  (u'comparable', 48),
#  (u'participation', 47),
#  (u'across', 46),
#  (u'health', 45),
#  (u'3', 44),
#  (u'research', 43),
#  (u'for', 42),
#  (u'sub', 41),
#  (u'scale', 40),
#  (u'subject', 39),
#  (u'et', 38),
#  (u'year', 37),
#  (u'result', 36),
#  (u'rate', 35),
#  (u'past', 34),
#  (u'we', 33),
#  (u'eg', 32),
#  (u'spring', 31),
#  (u'athletics', 30),
#  (u'found', 29),
#  (u'second', 28),
#  (u'p', 27),
#  (u'50', 26),
#  (u'accordance', 25),
#  (u'tobacco', 24),
#  (u'perceived', 23),
#  (u'day', 22),
#  (u'difference', 21),
#  (u'using', 20),
#  (u'negative', 19),
#  (u'test', 18),
#  (u'possible', 17),
#  (u'greater', 16),
#  (u'2012', 15),
#  (u'covered', 14),
#  (u'policy', 13),
#  (u'4', 12),
#  (u'program', 11),
#  (u'grade', 10),
#  (u'group', 9),
#  (u'le', 8),
#  (u'impact', 7),
#  (u'range', 6),
#  (u'attitude', 5),
#  (u'month', 4),
#  (u'random', 3),
#  (u'consent', 2),
#  (u'rounded', 1),
#  (u'limited', 0)]

# %%
#tfidf using gensim package
tfidf = gensim.models.tfidfmodel.TfidfModel(doc_term_matrix, id2word = dictionary)

# %%
#Fit corpus to get scores for terms in dictionary
corpus_tfidf = tfidf[doc_term_matrix]
word_score = {dictionary.get(id): value for doc in corpus_tfidf for id, value in doc}
#print(word_score)

# %%
#Sort by term scores
import operator
sorted_word_score = sorted(word_score.items(), key=operator.itemgetter(1),reverse=True)
sorted_word_score
# Out:
# [(u'4', 1.0),
#  (u'policy', 1.0),
#  (u'p', 1.0),
#  (u'research', 1.0),
#  (u'12', 1.0),
#  (u'j', 1.0),
#  (u'measure', 1.0),
#  (u'in', 1.0),
#  (u'5', 1.0),
#  (u'education', 0.9097298558352529),
#  (u'2', 0.8397540032818169),
#  (u'whether', 0.8239745925257059),
#  (u'2008', 0.7753567334050402),
#  (u'using', 0.7328280175142081),
#  (u'10', 0.7328280175142081),
#  (u'second', 0.7071067811865476),
#  (u'likely', 0.6809199143253225),
#  (u'random', 0.6804139157499614),
#  (u'14', 0.6528847313856487),
#  (u'period', 0.6521462389505934),
#  (u'range', 0.6395055420741893),
#  (u'health', 0.631523503888387),
#  (u'3', 0.6299769056354008),
#  (u'statistically', 0.6219058663282299),
#  (u'6', 0.6140925832335032),
#  (u'1', 0.6035420554991026),
#  (u'significant', 0.6018729660222095),
#  (u'survey', 0.5905258087194626),
#  (u'possible', 0.5624385926132234),
#  (u'measured', 0.5584477984793236),
#  (u'grant', 0.5544855398289232),
#  (u'greater', 0.5477436977084504),
#  (u'spillover', 0.5455247563286337),
#  (u'time', 0.5365154351260035),
#  (u'et', 0.5356031775127409),
#  (u'al', 0.5356031775127409),
#  (u's', 0.53141458247765),
#  (u'future', 0.5312314580373266),
#  (u'connection', 0.5247762989812257),
#  (u'participating', 0.5206585962081525),
#  (u'consent', 0.520045376239802),
#  (u'jamesburdumy', 0.511267646822216),
#  (u'extracurricular', 0.48733216518499306),
#  (u'result', 0.47476335466509423),
#  (u'outcome', 0.4705190506280816),
#  (u'response', 0.4556808940632597),
#  (u'high', 0.4499402039344298),
#  (u'athletics', 0.4493242146945793),
#  (u'however', 0.4493242146945793),
#  (u'first', 0.44705613843543524),
#  (u'national', 0.44705613843543524),
#  (u'for', 0.446205574390142),
#  (u'consequence', 0.44414798709122566),
#  (u'among', 0.43254368383360714),
#  (u'u', 0.4152006616107085),
#  (u'we', 0.41331092395567476),
#  (u'negative', 0.4123811642659322),
#  (u'indicate', 0.40924087255083264),
#  (u'higher', 0.40924087255083264),
#  (u'district', 0.40732964499594226),
#  (u'spring', 0.3948202062882156),
#  (u'rounded', 0.3931196051654338),
#  (u'publication', 0.3931196051654338),
#  (u'accordance', 0.3931196051654338),
#  (u'nearest', 0.3931196051654338),
#  (u'2007\u20132008', 0.38586236826508413),
#  (u'data', 0.3858175712648754),
#  (u'eg', 0.3846702050432455),
#  (u'toward', 0.37655235925798014),
#  (u'value', 0.37532173596503443),
#  (u'positive', 0.37411554748982273),
#  (u'analysis', 0.3732697811995076),
#  (u'participant', 0.3710983918186925),
#  (u'similar', 0.36968280307272916),
#  (u'group', 0.36790487242401837),
#  (u'finding', 0.36674879463701027),
#  (u'one', 0.35979092760817927),
#  (u'con', 0.35979092760817927),
#  (u'attitude', 0.3587787604750386),
#  (u'participated', 0.35566742620500835),
#  (u'limited', 0.35112692545248514),
#  (u'percentage', 0.34505441570464923),
#  (u'following', 0.34505441570464923),
#  (u'conducted', 0.34279065182219043),
#  (u'prior', 0.34279065182219043),
#  (u'comparable', 0.34045995716266125),
#  (u'nonparticipant', 0.338325662847548),
#  (u'without', 0.33421503490428994),
#  (u'tobacco', 0.32875044643241536),
#  (u'test', 0.32595461942749065),
#  (u'le', 0.32437307802891513),
#  (u'across', 0.32437307802891513),
#  (u'included', 0.32238278997148717),
#  (u'assignment', 0.3223396300364332),
#  (u'program', 0.313394628651774),
#  (u'size', 0.31279092103287837),
#  (u'coveredactivity', 0.3099866403929752),
#  (u'two', 0.3099866403929752),
#  (u'intention', 0.3069852732775813),
#  (u'alcohol', 0.3030246916072355),
#  (u'scale', 0.30156020818240553),
#  (u'followup', 0.298648415522301),
#  (u'impact', 0.28291510355334065),
#  (u'sample', 0.28078867088387066),
#  (u'covered', 0.27055266502182446),
#  (u'journal', 0.2656157290186633),
#  (u'172\u2013178', 0.2656157290186633),
#  (u'subject', 0.2569725306464957),
#  (u'50', 0.25554573248853374),
#  (u'three', 0.25554573248853374),
#  (u'2012', 0.24666336604978142),
#  (u'adolescent', 0.23871781851797103),
#  (u'stance', 0.23867341005652984),
#  (u'unintentional', 0.23867341005652984),
#  (u'sub', 0.23867341005652984),
#  (u'reported', 0.23764373426315225),
#  (u'to', 0.23029809925720013),
#  (u'district\u2019s', 0.21916696428827692),
#  (u'past', 0.20997709121862165),
#  (u'tested', 0.20997709121862165),
#  (u'within', 0.20201646107149032),
#  (u'evidence', 0.19579909081771601),
#  (u'participation', 0.18990372084399945),
#  (u'students\u2019', 0.18990372084399945),
#  (u'perceived', 0.18303146943332854),
#  (u'rate', 0.17498674606253453),
#  (u'found', 0.16297730971374533),
#  (u'day', 0.11501813856821641),
#  (u'account', 0.11501813856821641),
#  (u'connectedness', 0.11501813856821641),
#  (u'hypothesis', 0.10958348214413846),
#  (u'30', 0.10958348214413846),
#  (u'clustering', 0.10958348214413846),
#  (u'next', 0.10958348214413846),
#  (u'month', 0.10498854560931083),
#  (u'table', 0.08432715567877835),
#  (u'16', 0.08109819735513787),
#  (u'year', 0.08034684060521267),
#  (u'difference', 0.07853973673770716),
#  (u'grade', 0.07726627271504433),
#  (u'9th', 0.07726627271504433),
#  (u'baseline', 0.059458276744576)]

# %%
#tfidf using sklearn package
from sklearn.feature_extraction.text import TfidfVectorizer
tf = TfidfVectorizer(analyzer='word', ngram_range=(1,3), min_df = 0, stop_words = stop)
tfidf_matrix =  tf.fit_transform(docs)
feature_names = tf.get_feature_names() 
len(feature_names)
# Out:
# 6146

# %%
#print(feature_names)

# %%
#sort term scores
dense = tfidf_matrix.todense()
sentences = dense[0].tolist()[0]
phrase_scores = [pair for pair in zip(range(0, len(sentences)), sentences) if pair[1] > 0]
#sorted(phrase_scores, key=lambda t: t[1] * -1)

# %%
#Match term ID with term
sorted_phrase_scores = sorted(phrase_scores, key=lambda t: t[1] * -1)
for phrase, score in [(feature_names[word_id], score) for (word_id, score) in sorted_phrase_scores][:20]:
    print('{0: <20} {1}'.format(phrase, score))

# %% [markdown]
# ## Combine files for each type of violence

# %%
#Fight_assault_data
from io import open
import glob
path =r'/Users/aarya/Github/Lantern_v2/Data/SH_data'
allFiles = glob.glob(path + "/*.txt")
text = ''
for file in allFiles:
    with open(file, encoding='utf-8') as f:
        text = text + str(f.read())

# %%
texts = tokenizer.tokenize(text.decode('utf-8')) # add the decode function here to fix any unicodedecode errors
texts_clean = [clean(doc).split() for doc in texts]
dictionary = corpora.Dictionary(texts_clean)
dictionary.filter_extremes(no_above=0.5)
doc_term_matrix = [dictionary.doc2bow(doc) for doc in texts_clean]

#Words in the dictionary sorted by the number of time it appeared in the doc
sorted_dict = sorted(dictionary.token2id.items(), key=lambda x: x[1], reverse = True)
sorted_dict
# Out:
# [(u'simpson', 1898),
#  (u'rural', 1897),
#  (u'471', 1896),
#  (u'intentionally', 1895),
#  (u'eom', 1894),
#  (u'prevalent', 1893),
#  (u'communitybased', 1892),
#  (u'exposure', 1891),
#  (u'gap', 1890),
#  (u'chiodo', 1889),
#  (u'chance', 1888),
#  (u'variation', 1887),
#  (u'conclusion', 1886),
#  (u'concerning', 1885),
#  (u'mass', 1884),
#  (u'other', 1883),
#  (u'41', 1882),
#  (u'40', 1881),
#  (u'detail', 1880),
#  (u'42', 1879),
#  (u'45', 1878),
#  (u'44', 1877),
#  (u'47', 1876),
#  (u'46', 1875),
#  (u'variety', 1874),
#  (u'48', 1873),
#  (u'compared', 1872),
#  (u'inc', 1871),
#  (u'girl', 1870),
#  (u'education', 1869),
#  (u'83', 1868),
#  (u'sexually', 1867),
#  (u'problem', 1866),
#  (u'men\u2019s', 1865),
#  (u'89', 1864),
#  (u'88', 1863),
#  (u'official', 1862),
#  (u'whether', 1861),
#  (u'jaffe', 1860),
#  (u'made', 1859),
#  (u'he', 1858),
#  (u'highest', 1857),
#  (u'hierarchical', 1856),
#  (u'students\u2019', 1855),
#  (u'but', 1854),
#  (u'bus', 1853),
#  (u'north', 1852),
#  (u'function', 1851),
#  (u'recruited', 1850),
#  (u'spread', 1849),
#  (u'1988', 1848),
#  (u'egalitarian', 1847),
#  (u'confident', 1846),
#  (u'adolescent', 1845),
#  (u'additional', 1844),
#  (u'van', 1843),
#  (u'female', 1842),
#  (u'esteem', 1841),
#  (u'chronic', 1840),
#  (u'dataset', 1839),
#  (u'washington', 1838),
#  (u'software', 1837),
#  (u'predictor', 1836),
#  (u'gaylesbian', 1835),
#  (u'croninger', 1834),
#  (u'getting', 1833),
#  (u'collinearity', 1832),
#  (u'about', 1831),
#  (u'muth\xe9n', 1830),
#  (u'stage', 1829),
#  (u'r', 1828),
#  (u'although', 1827),
#  (u'epidemiology', 1826),
#  (u'journal', 1825),
#  (u'slur', 1824),
#  (u'islander', 1823),
#  (u'overlap', 1822),
#  (u'avoid', 1821),
#  (u'lead', 1820),
#  (u'118', 1819),
#  (u'119', 1818),
#  (u'peter', 1817),
#  (u'home', 1816),
#  (u'112', 1815),
#  (u'113', 1814),
#  (u'110', 1813),
#  (u'111', 1812),
#  (u'growth', 1811),
#  (u'117', 1810),
#  (u'114', 1809),
#  (u'kde', 1808),
#  (u'classical', 1807),
#  (u'because', 1806),
#  (u'poor', 1805),
#  (u'become', 1804),
#  (u'stonard', 1803),
#  (u'schmitt', 1802),
#  (u'success', 1801),
#  (u'like', 1800),
#  (u'intersection', 1799),
#  (u'press', 1798),
#  (u'479\u2013490', 1797),
#  (u'five', 1796),
#  (u'260', 1795),
#  (u'261', 1794),
#  (u'myth', 1793),
#  (u'increased', 1792),
#  (u'inperson', 1791),
#  (u'285', 1790),
#  (u'283', 1789),
#  (u'attractive', 1788),
#  (u'extends', 1787),
#  (u'add', 1786),
#  (u'daviskean', 1785),
#  (u'demographic', 1784),
#  (u'wei', 1783),
#  (u'\u2014', 1782),
#  (u'clinic', 1781),
#  (u'43', 1780),
#  (u'cisgender', 1779),
#  (u'domestic', 1778),
#  (u'accurate', 1777),
#  (u'percent', 1776),
#  (u'increasingly', 1775),
#  (u'drawing', 1774),
#  (u'352', 1773),
#  (u'perpetrate', 1772),
#  (u'well', 1771),
#  (u'49', 1770),
#  (u'weapon', 1769),
#  (u'i', 1768),
#  (u'center', 1767),
#  (u'identity', 1766),
#  (u'frequently', 1765),
#  (u'student', 1764),
#  (u'5\u20136', 1763),
#  (u'bullying', 1762),
#  (u'effect', 1761),
#  (u'upon', 1760),
#  (u'reporting', 1759),
#  (u'columbia', 1758),
#  (u'conflicting', 1757),
#  (u'difficult', 1756),
#  (u'yahner', 1755),
#  (u'propensity', 1754),
#  (u'member', 1753),
#  (u'campus', 1752),
#  (u'administration', 1751),
#  (u'perhaps', 1750),
#  (u'cohort', 1749),
#  (u'descriptive', 1748),
#  (u'regression', 1747),
#  (u'partner', 1746),
#  (u'chisquare', 1745),
#  (u'examined', 1744),
#  (u'site', 1743),
#  (u'thus', 1742),
#  (u'almost', 1741),
#  (u'examines', 1740),
#  (u'one\u2019s', 1739),
#  (u'at', 1738),
#  (u'value', 1737),
#  (u'aauw', 1736),
#  (u'imbalance', 1735),
#  (u'present', 1734),
#  (u'an', 1733),
#  (u'lgb', 1732),
#  (u'diversity', 1731),
#  (u'felix', 1730),
#  (u'rhode', 1729),
#  (u'discrimination', 1728),
#  (u'\xa9', 1727),
#  (u'mailman', 1726),
#  (u'largest', 1725),
#  (u'manhood', 1724),
#  (u'coercive', 1723),
#  (u'teasing', 1722),
#  (u'ca', 1721),
#  (u'relevant', 1720),
#  (u'adjusted', 1719),
#  (u'strongly', 1718),
#  (u'comment', 1717),
#  (u'otherwise', 1716),
#  (u'drug', 1715),
#  (u'equal', 1714),
#  (u'joke', 1713),
#  (u'nonlgbt', 1712),
#  (u'distribution', 1711),
#  (u'key', 1710),
#  (u'hypothesis', 1709),
#  (u'importance', 1708),
#  (u'ability', 1707),
#  (u'comparable', 1706),
#  (u'email', 1705),
#  (u'neither', 1704),
#  (u'288', 1703),
#  (u'state', 1702),
#  (u'favor', 1701),
#  (u'sociosexuality', 1700),
#  (u'pattern', 1699),
#  (u'error', 1698),
#  (u'creating', 1697),
#  (u'haselton', 1696),
#  (u'\u2013', 1695),
#  (u'yost', 1694),
#  (u'taiwanese', 1693),
#  (u'frame', 1692),
#  (u'j', 1691),
#  (u'view', 1690),
#  (u'she', 1689),
#  (u'influenced', 1688),
#  (u'differential', 1687),
#  (u'h', 1686),
#  (u'cooccurrence', 1685),
#  (u'evolution', 1684),
#  (u'kong', 1683),
#  (u'129', 1682),
#  (u'128', 1681),
#  (u'127', 1680),
#  (u'125', 1679),
#  (u'124', 1678),
#  (u'joint', 1677),
#  (u'120', 1676),
#  (u'overall', 1675),
#  (u'mortality', 1674),
#  (u'local', 1673),
#  (u'employed', 1672),
#  (u'institutional', 1671),
#  (u'knowledge', 1670),
#  (u'based', 1669),
#  (u'durant', 1668),
#  (u'staff', 1667),
#  (u'fear', 1666),
#  (u'planning', 1665),
#  (u'supported', 1664),
#  (u'text', 1663),
#  (u'selection', 1662),
#  (u'atmosphere', 1661),
#  (u'fact', 1660),
#  (u'gesture', 1659),
#  (u'disease', 1658),
#  (u'request', 1657),
#  (u'inappropriate', 1656),
#  (u'class', 1655),
#  (u'preliminary', 1654),
#  (u'connected', 1653),
#  (u'said', 1652),
#  (u'harmful', 1651),
#  (u'messerschmidt', 1650),
#  (u'latino', 1649),
#  (u'325', 1648),
#  (u'tactic', 1647),
#  (u'327', 1646),
#  (u'agecohort', 1645),
#  (u'instance', 1644),
#  (u'able', 1643),
#  (u'min', 1642),
#  (u'\u03c72', 1641),
#  (u'afraid', 1640),
#  (u'linked', 1639),
#  (u'selfreport', 1638),
#  (u'need', 1637),
#  (u'cohen', 1636),
#  (u'bisexual', 1635),
#  (u'providing', 1634),
#  (u'johnson', 1633),
#  (u'kosciw', 1632),
#  (u'morbidity', 1631),
#  (u'environmental', 1630),
#  (u'completed', 1629),
#  (u'final', 1628),
#  (u'racist', 1627),
#  (u'onenight', 1626),
#  (u'data', 1625),
#  (u'table', 1624),
#  (u'publication', 1623),
#  (u'quality', 1622),
#  (u'ybarra', 1621),
#  (u'blackwell', 1620),
#  (u'south', 1619),
#  (u'samesex', 1618),
#  (u'hence', 1617),
#  (u'ltd', 1616),
#  (u'length', 1615),
#  (u'counterpart', 1614),
#  (u'mac', 1613),
#  (u'could', 1612),
#  (u'g', 1611),
#  (u'hostile', 1610),
#  (u'interaction', 1609),
#  (u'scary', 1608),
#  (u'likelihood', 1607),
#  (u'delinquency', 1606),
#  (u'york', 1605),
#  (u'attending', 1604),
#  (u'hamby', 1603),
#  (u'activity', 1602),
#  (u'retrieved', 1601),
#  (u'cause', 1600),
#  (u'adverse', 1599),
#  (u'category', 1598),
#  (u'85', 1597),
#  (u'special', 1596),
#  (u'87', 1595),
#  (u'sexual', 1594),
#  (u'81', 1593),
#  (u'80', 1592),
#  (u'our', 1591),
#  (u'82', 1590),
#  (u'measure', 1589),
#  (u'frequency', 1588),
#  (u'hlm', 1587),
#  (u'society', 1586),
#  (u'related', 1585),
#  (u'hpol', 1584),
#  (u'weimer', 1583),
#  (u'mode', 1582),
#  (u'pathway', 1581),
#  (u'identified', 1580),
#  (u'university', 1579),
#  (u'continuum', 1578),
#  (u'day', 1577),
#  (u'documented', 1576),
#  (u'practice', 1575),
#  (u'greater', 1574),
#  (u'2012', 1573),
#  (u'2013', 1572),
#  (u'2010', 1571),
#  (u'2011', 1570),
#  (u'2016', 1569),
#  (u'2014', 1568),
#  (u'2015', 1567),
#  (u'exclusion', 1566),
#  (u'longitudinal', 1565),
#  (u'le', 1564),
#  (u'246\u2013252', 1563),
#  (u'134', 1562),
#  (u'obstetrics', 1561),
#  (u'136', 1560),
#  (u'including', 1559),
#  (u'130', 1558),
#  (u'131', 1557),
#  (u'133', 1556),
#  (u'competing', 1555),
#  (u'gynecology', 1554),
#  (u'soiattitudes', 1553),
#  (u'evolutionary', 1552),
#  (u'allow', 1551),
#  (u'espelage', 1550),
#  (u'queer', 1549),
#  (u'ethnic', 1548),
#  (u'abuse', 1547),
#  (u'sameethnicity', 1546),
#  (u'dc', 1545),
#  (u'oppositesex', 1544),
#  (u'yrbs', 1543),
#  (u'administrator', 1542),
#  (u'profile', 1541),
#  (u'attachment', 1540),
#  (u'hampshire', 1539),
#  (u'varied', 1538),
#  (u'united', 1537),
#  (u'educational', 1536),
#  (u'native', 1535),
#  (u'rape', 1534),
#  (u'something', 1533),
#  (u'high', 1532),
#  (u'crick', 1531),
#  (u'process', 1530),
#  (u'reserved', 1529),
#  (u'control', 1528),
#  (u'dropped', 1527),
#  (u'of', 1526),
#  (u'anywhere', 1525),
#  (u'when', 1524),
#  (u'challenge', 1523),
#  (u'this', 1522),
#  (u'f', 1521),
#  (u'account', 1520),
#  (u'occurred', 1519),
#  (u'becomes', 1518),
#  (u'started', 1517),
#  (u'on', 1516),
#  (u'surveyed', 1515),
#  (u'panel', 1514),
#  (u'expanding', 1513),
#  (u'examination', 1512),
#  (u'next', 1511),
#  (u'remains', 1510),
#  (u'usa', 1509),
#  (u'from', 1508),
#  (u'confidence', 1507),
#  (u'addressed', 1506),
#  (u'shoved', 1505),
#  (u'examining', 1504),
#  (u'maker', 1503),
#  (u'chang', 1502),
#  (u'survey', 1501),
#  (u'suggests', 1500),
#  (u'34', 1499),
#  (u'35', 1498),
#  (u'36', 1497),
#  (u'37', 1496),
#  (u'30', 1495),
#  (u'31', 1494),
#  (u'involved', 1493),
#  (u'receive', 1492),
#  (u'engage', 1491),
#  (u'remark', 1490),
#  (u'others', 1489),
#  (u'focused', 1488),
#  (u'explore', 1487),
#  (u'growing', 1486),
#  (u'leo', 1485),
#  (u'wolak', 1484),
#  (u'respectively', 1483),
#  (u'upsetting', 1482),
#  (u'degree', 1481),
#  (u'lee', 1480),
#  (u'pediatrics', 1479),
#  (u'impact', 1478),
#  (u'body', 1477),
#  (u'harassing', 1476),
#  (u'3a', 1475),
#  (u'3b', 1474),
#  (u'consistently', 1473),
#  (u'cell', 1472),
#  (u'chicago', 1471),
#  (u'junior', 1470),
#  (u'index', 1469),
#  (u'depression', 1468),
#  (u'pornography', 1467),
#  (u'uncomfortable', 1466),
#  (u'basile', 1465),
#  (u'crook', 1464),
#  (u'participate', 1463),
#  (u'noted', 1462),
#  (u'race', 1461),
#  (u'fewer', 1460),
#  (u'experiencing', 1459),
#  (u'entire', 1458),
#  (u'continued', 1457),
#  (u'drinking', 1456),
#  (u'outside', 1455),
#  (u'indicating', 1454),
#  (u'include', 1453),
#  (u'quarterly', 1452),
#  (u'excluded', 1451),
#  (u'ebullied', 1450),
#  (u'\u201cbullying\u201d', 1449),
#  (u'young', 1448),
#  (u'simon', 1447),
#  (u'adjustment', 1446),
#  (u'go', 1445),
#  (u'017', 1444),
#  (u'013', 1443),
#  (u'010', 1442),
#  (u'existing', 1441),
#  (u'having', 1440),
#  (u'requires', 1439),
#  (u'2009', 1438),
#  (u'2008', 1437),
#  (u'international', 1436),
#  (u'psychiatry', 1435),
#  (u'2005', 1434),
#  (u'2004', 1433),
#  (u'2007', 1432),
#  (u'2006', 1431),
#  (u'2001', 1430),
#  (u'2000', 1429),
#  (u'2003', 1428),
#  (u'2002', 1427),
#  (u'wellbeing', 1426),
#  (u'required', 1425),
#  (u'age', 1424),
#  (u'e', 1423),
#  (u'antecedent', 1422),
#  (u'structure', 1421),
#  (u'aggregated', 1420),
#  (u'developmental', 1419),
#  (u'explaining', 1418),
#  (u'department', 1417),
#  (u'income', 1416),
#  (u'coded', 1415),
#  (u'accounted', 1414),
#  (u'grouped', 1413),
#  (u'employment', 1412),
#  (u'harassment\u201d', 1411),
#  (u'supportive', 1410),
#  (u'racial', 1409),
#  (u'graham', 1408),
#  (u'organizational', 1407),
#  (u'diverse', 1406),
#  (u'single', 1405),
#  (u'influence', 1404),
#  (u'defined', 1403),
#  (u'associated', 1402),
#  (u'schonlau', 1401),
#  (u'medical', 1400),
#  (u'similar', 1399),
#  (u'highlight', 1398),
#  (u'thijs', 1397),
#  (u'uk', 1396),
#  (u'raceethnicity', 1395),
#  (u'access', 1394),
#  (u'characteristic', 1393),
#  (u'gangestad', 1392),
#  (u'considerable', 1391),
#  (u'line', 1390),
#  (u'juvonen', 1389),
#  (u'externalizing', 1388),
#  (u'link', 1387),
#  (u'linn', 1386),
#  (u'adjusting', 1385),
#  (u'great', 1384),
#  (u'78', 1383),
#  (u'79', 1382),
#  (u'handbook', 1381),
#  (u'specifically', 1380),
#  (u'question', 1379),
#  (u'measured', 1378),
#  (u'pepler', 1377),
#  (u'primarily', 1376),
#  (u'appropriate', 1375),
#  (u'harasser', 1374),
#  (u'within', 1373),
#  (u'harassed', 1372),
#  (u'schoolbased', 1371),
#  (u'block', 1370),
#  (u'consequently', 1369),
#  (u'messaging', 1368),
#  (u'range', 1367),
#  (u'completing', 1366),
#  (u'by', 1365),
#  (u'step', 1364),
#  (u'use', 1363),
#  (u'304', 1362),
#  (u'palmer', 1361),
#  (u'selfreports', 1360),
#  (u'patient', 1359),
#  (u't', 1358),
#  (u'dating', 1357),
#  (u'masculinity', 1356),
#  (u'pew', 1355),
#  (u'scale', 1354),
#  (u'soibehavior', 1353),
#  (u'added', 1352),
#  (u'some', 1351),
#  (u'often', 1350),
#  (u'healthy', 1349),
#  (u'disorder', 1348),
#  (u'continue', 1347),
#  (u'separately', 1346),
#  (u'maltreatment', 1345),
#  (u'follows', 1344),
#  (u'd', 1343),
#  (u'hanish', 1342),
#  (u'stein', 1341),
#  (u'complaint', 1340),
#  (u'relevance', 1339),
#  (u'source', 1338),
#  (u'exclusively', 1337),
#  (u'malanchuk', 1336),
#  (u'also', 1335),
#  (u'268', 1334),
#  (u'discipline', 1333),
#  (u'alternative', 1332),
#  (u'using', 1331),
#  (u'hypothesized', 1330),
#  (u'know', 1329),
#  (u'prevention', 1328),
#  (u'organization', 1327),
#  (u'y', 1326),
#  (u'consistency', 1325),
#  (u'person', 1324),
#  (u'analysis', 1323),
#  (u'10\u201315', 1322),
#  (u'lower', 1321),
#  (u'recent', 1320),
#  (u'009', 1319),
#  (u'user', 1318),
#  (u'001', 1317),
#  (u'comprehensive', 1316),
#  (u'greytak', 1315),
#  (u'pediatric', 1314),
#  (u'literature', 1313),
#  (u'hallway', 1312),
#  (u'development', 1311),
#  (u'higher', 1310),
#  (u'conflict', 1309),
#  (u'composition', 1308),
#  (u'9', 1307),
#  (u'widely', 1306),
#  (u'emphasize', 1305),
#  (u'elevated', 1304),
#  (u'perpetrator', 1303),
#  (u'aged', 1302),
#  (u'ethnicity', 1301),
#  (u'nondistressing', 1300),
#  (u'individuallevel', 1299),
#  (u'larger', 1298),
#  (u'mitchell', 1297),
#  (u'32', 1296),
#  (u'behavior', 1295),
#  (u'sexuality', 1294),
#  (u'33', 1293),
#  (u'empirical', 1292),
#  (u'straight', 1291),
#  (u'look', 1290),
#  (u'systematic', 1289),
#  (u'representative', 1288),
#  (u'understand', 1287),
#  (u'38', 1286),
#  (u'\u204e', 1285),
#  (u'39', 1284),
#  (u'gay', 1283),
#  (u'0001', 1282),
#  (u'partly', 1281),
#  (u'threaten', 1280),
#  (u'collected', 1279),
#  (u'lenhart', 1278),
#  (u'strategy', 1277),
#  (u'due', 1276),
#  (u'create', 1275),
#  (u'toomey', 1274),
#  (u'described', 1273),
#  (u'pp', 1272),
#  (u'throughout', 1271),
#  (u'community', 1270),
#  (u'smith', 1269),
#  (u'point', 1268),
#  (u'distress', 1267),
#  (u'childhood', 1266),
#  (u'context', 1265),
#  (u'influential', 1264),
#  (u'last', 1263),
#  (u'10th', 1262),
#  (u'c', 1261),
#  (u'both', 1260),
#  (u'legislature', 1259),
#  (u'\u201csexual', 1258),
#  (u'incident', 1257),
#  (u'attention', 1256),
#  (u'targeted', 1255),
#  (u'missing', 1254),
#  (u'statistically', 1253),
#  (u'recently', 1252),
#  (u'available', 1251),
#  (u'stratified', 1250),
#  (u'numerous', 1249),
#  (u'mcmaster', 1248),
#  (u'various', 1247),
#  (u'determined', 1246),
#  (u'multinomial', 1245),
#  (u'currently', 1244),
#  (u'project', 1243),
#  (u'eccles', 1242),
#  (u'11th', 1241),
#  (u'are', 1240),
#  (u'individual', 1239),
#  (u'see', 1238),
#  (u'culture', 1237),
#  (u'sex', 1236),
#  (u'tended', 1235),
#  (u'september', 1234),
#  (u'set', 1233),
#  (u'river', 1232),
#  (u'withdrawal', 1231),
#  (u'logistic', 1230),
#  (u'common', 1229),
#  (u'investigate', 1228),
#  (u'\u2264', 1227),
#  (u'collins', 1226),
#  (u'theft', 1225),
#  (u'gendered', 1224),
#  (u'hit', 1223),
#  (u'timmerman', 1222),
#  (u'8', 1221),
#  (u'factor', 1220),
#  (u'positively', 1219),
#  (u'13\u201315', 1218),
#  (u'justice', 1217),
#  (u'delinquent', 1216),
#  (u'causality', 1215),
#  (u'indicator', 1214),
#  (u'wolfe', 1213),
#  (u'distressing', 1212),
#  (u'find', 1211),
#  (u'relation', 1210),
#  (u'cdc', 1209),
#  (u'particularly', 1208),
#  (u'bulletin', 1207),
#  (u'kt', 1206),
#  (u'traditional', 1205),
#  (u'clear', 1204),
#  (u'kj', 1203),
#  (u'victimization', 1202),
#  (u'achievement', 1201),
#  (u'approved', 1200),
#  (u'extremely', 1199),
#  (u'70', 1198),
#  (u'significant', 1197),
#  (u'72', 1196),
#  (u'73', 1195),
#  (u'74', 1194),
#  (u'75', 1193),
#  (u'most', 1192),
#  (u'77', 1191),
#  (u'experienced', 1190),
#  (u'play', 1189),
#  (u'finding', 1188),
#  (u'internal', 1187),
#  (u'majority', 1186),
#  (u'heterosexual', 1185),
#  (u'self', 1184),
#  (u'depending', 1183),
#  (u'vulnerable', 1182),
#  (u'null', 1181),
#  (u'elsevier', 1180),
#  (u'substantial', 1179),
#  (u'randomly', 1178),
#  (u'straightheterosexual', 1177),
#  (u'urban', 1176),
#  (u'motivation', 1175),
#  (u'interactive', 1174),
#  (u'toward', 1173),
#  (u'hyde', 1172),
#  (u'dank', 1171),
#  (u'stressor', 1170),
#  (u'youth', 1169),
#  (u'df1', 1168),
#  (u'instruction', 1167),
#  (u'b', 1166),
#  (u'kind', 1165),
#  (u'believe', 1164),
#  (u'part', 1163),
#  (u'checklist', 1162),
#  (u'bowen', 1161),
#  (u'relationship', 1160),
#  (u'option', 1159),
#  (u'189', 1158),
#  (u'186', 1157),
#  (u'182', 1156),
#  (u'construct', 1155),
#  (u'moderately', 1154),
#  (u'5th', 1153),
#  (u'leading', 1152),
#  (u'introduction', 1151),
#  (u'utilization', 1150),
#  (u'bullied', 1149),
#  (u'least', 1148),
#  (u'done', 1147),
#  (u'utilized', 1146),
#  (u'reflected', 1145),
#  (u'sakaguchi', 1144),
#  (u'feel', 1143),
#  (u'probability', 1142),
#  (u'major', 1141),
#  (u'grossman', 1140),
#  (u'consequence', 1139),
#  (u'w', 1138),
#  (u'prejudice', 1137),
#  (u'american', 1136),
#  (u'excluding', 1135),
#  (u'definition', 1134),
#  (u'beginning', 1133),
#  (u'ask', 1132),
#  (u'base', 1131),
#  (u'reason', 1130),
#  (u'nationally', 1129),
#  (u'disagree', 1128),
#  (u'lawrence', 1127),
#  (u'bully', 1126),
#  (u'ass', 1125),
#  (u'occurs', 1124),
#  (u'issue', 1123),
#  (u'offline', 1122),
#  (u'7', 1121),
#  (u'hill', 1120),
#  (u'safety', 1119),
#  (u'orientationgender', 1118),
#  (u'research', 1117),
#  (u'since', 1116),
#  (u'electronic', 1115),
#  (u'item', 1114),
#  (u'psychology', 1113),
#  (u'funding', 1112),
#  (u'perry', 1111),
#  (u'really', 1110),
#  (u'event', 1109),
#  (u'beyond', 1108),
#  (u'fineran', 1107),
#  (u'measurement', 1106),
#  (u'ryan', 1105),
#  (u'280\u2013295', 1104),
#  (u'reduce', 1103),
#  (u'weight', 1102),
#  (u'mental', 1101),
#  (u'england', 1100),
#  (u'harm', 1099),
#  (u'status', 1098),
#  (u'friendship', 1097),
#  (u'found', 1096),
#  (u'gender', 1095),
#  (u'connolly', 1094),
#  (u'level', 1093),
#  (u'goldstein', 1092),
#  (u'association', 1091),
#  (u'oxford', 1090),
#  (u'framework', 1089),
#  (u'number', 1088),
#  (u'garafalo', 1087),
#  (u'peskin', 1086),
#  (u'good', 1085),
#  (u'colleague', 1084),
#  (u'might', 1083),
#  (u'differed', 1082),
#  (u'disclosed', 1081),
#  (u'researcher', 1080),
#  (u'29', 1079),
#  (u'28', 1078),
#  (u'intraparental', 1077),
#  (u'highsoi', 1076),
#  (u'23', 1075),
#  (u'22', 1074),
#  (u'21', 1073),
#  (u'20', 1072),
#  (u'27', 1071),
#  (u'26', 1070),
#  (u'25', 1069),
#  (u'24', 1068),
#  (u'paper', 1067),
#  (u'attitude', 1066),
#  (u'held', 1065),
#  (u'dichotomous', 1064),
#  (u'developed', 1063),
#  (u'attitudinal', 1062),
#  (u'help', 1061),
#  (u'responsibility', 1060),
#  (u'1\u20132', 1059),
#  (u'jiang', 1058),
#  (u'a', 1057),
#  (u'response', 1056),
#  (u'participant', 1055),
#  (u'reflect', 1054),
#  (u'questioning', 1053),
#  (u'wiley', 1052),
#  (u'intended', 1051),
#  (u'explains', 1050),
#  (u'everyday', 1049),
#  (u'conducted', 1048),
#  (u'rather', 1047),
#  (u'information', 1046),
#  (u'robinson', 1045),
#  (u'sense', 1044),
#  (u'pushed', 1043),
#  (u'share', 1042),
#  (u'hamburger', 1041),
#  (u'compare', 1040),
#  (u'benbenishty', 1039),
#  (u'male', 1038),
#  (u'v', 1037),
#  (u'evolved', 1036),
#  (u'sent', 1035),
#  (u'nine', 1034),
#  (u'witkowska', 1033),
#  (u'equation', 1032),
#  (u'science', 1031),
#  (u'middle', 1030),
#  (u'none', 1029),
#  (u'town', 1028),
#  (u'largescale', 1027),
#  (u'known', 1026),
#  (u'particular', 1025),
#  (u'controlling', 1024),
#  (u'masculine', 1023),
#  (u'teen', 1022),
#  (u'more', 1021),
#  (u'16\u201317', 1020),
#  (u'taken', 1019),
#  (u'6', 1018),
#  (u'comparing', 1017),
#  (u'strauss', 1016),
#  (u'two', 1015),
#  (u'bohara', 1014),
#  (u'distinct', 1013),
#  (u'0', 1012),
#  (u'silva', 1011),
#  (u'select', 1010),
#  (u'coercion', 1009),
#  (u'5139', 1008),
#  (u'semester', 1007),
#  (u'put', 1006),
#  (u'family', 1005),
#  (u'followed', 1004),
#  (u'via', 1003),
#  (u'selfadministered', 1002),
#  (u'action', 1001),
#  (u'social', 1000),
#  (u'bendixen', 999),
#  (u'prior', 998),
#  (u'experience', 997),
#  (u'allows', 996),
#  (u'3\u20134', 995),
#  (u'publisher', 994),
#  (u'respect', 993),
#  (u'strong', 992),
#  (u'component', 991),
#  (u'ma', 990),
#  (u'lesbianqueer', 989),
#  (u'ranged', 988),
#  (u'contrast', 987),
#  (u'method', 986),
#  (u'diaz', 985),
#  (u'brief', 984),
#  (u'sum', 983),
#  (u'psychosomatic', 982),
#  (u'witnessed', 981),
#  (u'what', 980),
#  (u'belief', 979),
#  (u'casual', 978),
#  (u'functioning', 977),
#  (u'grabe', 976),
#  (u'further', 975),
#  (u'perspective', 974),
#  (u'design', 973),
#  (u'rate', 972),
#  (u'past', 971),
#  (u'190', 970),
#  (u'andor', 969),
#  (u'collinsworth', 968),
#  (u'biological', 967),
#  (u'small', 966),
#  (u'large', 965),
#  (u'nonwhite', 964),
#  (u'evaluation', 963),
#  (u'condition', 962),
#  (u'difference', 961),
#  (u'weighting', 960),
#  (u'very', 959),
#  (u'dohmh', 958),
#  (u'woman', 957),
#  (u'norm', 956),
#  (u'health', 955),
#  (u'program', 954),
#  (u'to', 953),
#  (u'\u2020', 952),
#  (u'covariates', 951),
#  (u'month', 950),
#  (u'lack', 949),
#  (u'suburban', 948),
#  (u'chinese', 947),
#  (u'consider', 946),
#  (u'all', 945),
#  (u'represent', 944),
#  (u'oral', 943),
#  (u'behavioral', 942),
#  (u'u', 941),
#  (u'odds', 940),
#  (u'building', 939),
#  (u'alcohol', 938),
#  (u'486', 937),
#  (u'included', 936),
#  (u'important', 935),
#  (u'includes', 934),
#  (u'separate', 933),
#  (u'oneself', 932),
#  (u'deviation', 931),
#  (u'5point', 930),
#  (u'you', 929),
#  (u'5', 928),
#  (u'valid', 927),
#  (u'bremer', 926),
#  (u'cyberbullying', 925),
#  (u'personnel', 924),
#  (u'women\u2019s', 923),
#  (u'assessing', 922),
#  (u'unwelcome', 921),
#  (u'gruber', 920),
#  (u'corresponding', 919),
#  (u'girlfriend', 918),
#  (u'together', 917),
#  (u'reliability', 916),
#  (u'examine', 915),
#  (u'general', 914),
#  (u'al', 913),
#  (u'describe', 912),
#  (u'certain', 911),
#  (u'detailed', 910),
#  (u'expect', 909),
#  (u'agree', 908),
#  (u'designbased', 907),
#  (u'romantic', 906),
#  (u'shortterm', 905),
#  (u'with', 904),
#  (u'regard', 903),
#  (u'complete', 902),
#  (u'nansel', 901),
#  (u'low', 900),
#  (u'sociosexual', 899),
#  ...]

# %%
#tfidf using gensim package
tfidf = gensim.models.tfidfmodel.TfidfModel(doc_term_matrix, id2word = dictionary)
corpus_tfidf = tfidf[doc_term_matrix]
word_score = {dictionary.get(id): value for doc in corpus_tfidf for id, value in doc}
sorted_word_score = sorted(word_score.items(), key=operator.itemgetter(1),reverse=True)
sorted_word_score
# Out:
# [(u'1995', 1.0),
#  (u'1997', 1.0),
#  (u'1996', 1.0),
#  (u'swearer', 1.0),
#  (u'2000a', 1.0),
#  (u'1979', 1.0),
#  (u'221', 1.0),
#  (u'ma', 1.0),
#  (u'college', 1.0),
#  (u'on', 1.0),
#  (u'u', 1.0),
#  (u'kt', 1.0),
#  (u'theft', 1.0),
#  (u'pp', 1.0),
#  (u'9', 1.0),
#  (u'2009', 1.0),
#  (u'leo', 1.0),
#  (u'2013', 1.0),
#  (u'simpson', 1.0),
#  (u'keywords', 0.9449657776175251),
#  (u'111', 0.9103203810070124),
#  (u'concept', 0.8966035023729834),
#  (u'hand', 0.891468077040608),
#  (u'51', 0.8712730356946504),
#  (u'society', 0.8653772638810109),
#  (u'pearson', 0.8616299429840025),
#  (u'eom', 0.8453013098323015),
#  (u'adolesc', 0.828276063954829),
#  (u'control', 0.8240949728655488),
#  (u'288', 0.8135212482458828),
#  (u'ca', 0.8119551424863626),
#  (u'290', 0.8060820939046603),
#  (u'chicago', 0.8060820939046603),
#  (u'witkowska', 0.805638299892356),
#  (u'good', 0.8011206398531133),
#  (u'success', 0.8011206398531133),
#  (u'vulnerable', 0.7969116826338224),
#  (u'2002', 0.795900701074588),
#  (u'attarschwartz', 0.7931922752893724),
#  (u'8', 0.7916266397819327),
#  (u'lead', 0.7906044869464998),
#  (u'g', 0.7901127816852168),
#  (u'118', 0.7886721473803079),
#  (u'collins', 0.7880541706000934),
#  (u'berger', 0.7801382881366871),
#  (u'1994', 0.7788479023899295),
#  (u'58', 0.7741706375170038),
#  (u'justice', 0.7685594920117774),
#  (u'128', 0.761229721829172),
#  (u'59', 0.7581605337125848),
#  (u'81', 0.7572521436298074),
#  (u'486', 0.7531230315818198),
#  (u'john', 0.752670807905844),
#  (u'101', 0.7461016637157215),
#  (u'men\u2019s', 0.7428972193401095),
#  (u'timmerman', 0.7416222453319168),
#  (u'\u2020', 0.7366050945611254),
#  (u'35', 0.7303024674419798),
#  (u'environmental', 0.7295946644670271),
#  (u'49', 0.7277277852317258),
#  (u'september', 0.7261195934286173),
#  (u'achievement', 0.7257701682247071),
#  (u'publication', 0.7212718798984074),
#  (u'final', 0.7212127130083731),
#  (u'fredland', 0.7187772272588455),
#  (u'133', 0.7184382231418577),
#  (u'tropp', 0.7152382029153344),
#  (u'\u204e\u204e', 0.7152382029153344),
#  (u'strongly', 0.7139159780107748),
#  (u'selfreported', 0.7102210188153323),
#  (u'guerra', 0.7071067811865476),
#  (u'hanish', 0.7071067811865476),
#  (u'50', 0.7035024259400248),
#  (u'32', 0.7024668923610877),
#  (u'truancy', 0.7013503786094292),
#  (u'pb01', 0.6988807574189199),
#  (u'pettigrew', 0.6988807574189199),
#  (u'covariates', 0.6957748207585834),
#  (u'slightly', 0.6949595351020718),
#  (u'not', 0.6932240802446102),
#  (u'41', 0.6887437897314416),
#  (u'39', 0.6879183423916914),
#  (u'42', 0.6879183423916914),
#  (u'campaign', 0.6878498433499596),
#  (u'women\u2019s', 0.6854994817193915),
#  (u'campbell', 0.6848657729318702),
#  (u'nj', 0.6839513718822345),
#  (u'se', 0.6821154962235365),
#  (u'olweus', 0.6795546603985906),
#  (u'21', 0.6756618821186202),
#  (u'what', 0.6750610550128838),
#  (u'36', 0.6743620382314701),
#  (u'messerschmidt', 0.673284677487787),
#  (u'commonly', 0.6697595773137284),
#  (u'assistant', 0.66940182302611),
#  (u'over', 0.6692180033003192),
#  (u'shute', 0.6682369811496734),
#  (u'desire', 0.6641192800706036),
#  (u'international', 0.6613547574302961),
#  (u'246\u2013252', 0.660483364686625),
#  (u'aggressive', 0.6584018825235234),
#  (u'34', 0.655993512790682),
#  (u'south', 0.6554823476063978),
#  (u'america', 0.651428233212176),
#  (u'institute', 0.6485297788481933),
#  (u'checked', 0.648352702433699),
#  (u'instance', 0.6467745703214414),
#  (u'40', 0.645904059756596),
#  (u'espelage', 0.6458837496536691),
#  (u'001', 0.6455943892320812),
#  (u'allen', 0.6439593419212093),
#  (u'thijs', 0.6415653398407369),
#  (u'multidimensional', 0.6411891074054281),
#  (u'growing', 0.6395374115171996),
#  (u'schneider', 0.637072057079515),
#  (u'bolen', 0.6362809577862464),
#  (u'everyday', 0.6355221356077152),
#  (u'bulletin', 0.63494859437139),
#  (u'measuring', 0.6343017360180038),
#  (u'05', 0.634067694369349),
#  (u'yost', 0.6332401825959254),
#  (u'86', 0.6309537276782465),
#  (u'selfreports', 0.630124356259311),
#  (u'\u2264', 0.6298457158689891),
#  (u'pedro', 0.6296993608671854),
#  (u'chinese', 0.6286822883563223),
#  (u'01', 0.6277397108363895),
#  (u'resnick', 0.6262980947793213),
#  (u'law', 0.6250159839026739),
#  (u'software', 0.6202311690557698),
#  (u'verkuyten', 0.6193788917335723),
#  (u'97', 0.6183103564762071),
#  (u'against', 0.6179724091684969),
#  (u'masculinity', 0.6155867093340934),
#  (u'pediatrics', 0.6148139913392783),
#  (u'selfadministered', 0.6140204520178539),
#  (u'lowest', 0.6132075704913115),
#  (u'schooling', 0.6126340887549017),
#  (u'overlap', 0.6126148611168974),
#  (u'mennemeier', 0.6109040741992584),
#  (u'crick', 0.6104571536900293),
#  (u'2015', 0.6098427561830702),
#  (u'brown', 0.6091724689457376),
#  (u'said', 0.6088119434013527),
#  (u'17', 0.6075876144499588),
#  (u'harassed', 0.6067149134353742),
#  (u'free', 0.605608559906272),
#  (u'43', 0.6039976836367106),
#  (u'110', 0.603896151093395),
#  (u'91\u2013105', 0.6032109447442396),
#  (u'peter', 0.6029946447108321),
#  (u'probability', 0.60281400026681),
#  (u'gangestad', 0.6024627024433811),
#  (u'competition', 0.6007134433736548),
#  (u'68', 0.5996077201020336),
#  (u'science', 0.5989988925591002),
#  (u'victim', 0.5973755282725519),
#  (u'kearl', 0.5967333515664087),
#  (u'childhood', 0.5964342231260709),
#  (u'02', 0.5939635251835755),
#  (u'2003', 0.5922287420226866),
#  (u'quarterly', 0.5921609753509721),
#  (u'bellmore', 0.5918653406977855),
#  (u'author', 0.5918037325721073),
#  (u'methodology', 0.5916070538704977),
#  (u'larson', 0.5915559597370728),
#  (u'handbook', 0.5883116523224481),
#  (u'biological', 0.5878991733979998),
#  (u'ghaill', 0.5871456048605049),
#  (u'mac', 0.5871456048605049),
#  (u'ryan', 0.5859452071131552),
#  (u'erlbaum', 0.5844404077324076),
#  (u'work', 0.5842563386029008),
#  (u'47', 0.5839780518597164),
#  (u'learning', 0.5834762279480736),
#  (u'drawing', 0.582936612338864),
#  (u'press', 0.5826498297071213),
#  (u'pb05', 0.5819289264283249),
#  (u'assessment', 0.5807673505763123),
#  (u'2012', 0.5785014139540069),
#  (u'you', 0.5778101695144351),
#  (u'friendship', 0.5764297412571473),
#  (u'river', 0.5752496774667771),
#  (u'is', 0.5747192936570152),
#  (u'silva', 0.5743144388012683),
#  (u'lawrence', 0.5737723458871025),
#  (u'service', 0.573483179598291),
#  (u'descriptive', 0.5721160478732583),
#  (u'evolutionary', 0.5717739451391283),
#  (u'79', 0.5704664511888264),
#  (u'researcher', 0.5698816836769692),
#  (u'men', 0.5685015501533719),
#  (u'222', 0.5677778819423761),
#  (u'coerced', 0.5676930736403442),
#  (u'stereotype', 0.5675456547372439),
#  (u'pew', 0.5668110121265818),
#  (u'children\u2019s', 0.5650081162332402),
#  (u'hasegawa', 0.5638673297408986),
#  (u'psychosomatic', 0.562999967258934),
#  (u'psychopathology', 0.5622567460775079),
#  (u'ever', 0.5615062311562152),
#  (u'ed', 0.5606652194746965),
#  (u'investigation', 0.5603690198054755),
#  (u'psychiatry', 0.5601944460521829),
#  (u'confucian', 0.5595458579474405),
#  (u'size', 0.5582223780812247),
#  (u'line', 0.5580564353356409),
#  (u'campus', 0.5580564353356409),
#  (u'11', 0.5568463986588932),
#  (u'cohen', 0.5565129593399762),
#  (u'26', 0.5564936486415991),
#  (u'ref', 0.5561058186962087),
#  (u'metaanalysis', 0.555334052082254),
#  (u'kimmel', 0.5549540023652442),
#  (u'highsoi', 0.5548540248888398),
#  (u'robinson', 0.5538053341692583),
#  (u'conference', 0.5535212968969049),
#  (u'felix', 0.5528025706347243),
#  (u'103', 0.5517001794993791),
#  (u'focused', 0.5508476470325252),
#  (u'intergroup', 0.5505025675933292),
#  (u'010', 0.5499606567530125),
#  (u'limitation', 0.5497272804579473),
#  (u'instrument', 0.5492699774341911),
#  (u'kj', 0.5491739754432586),
#  (u'accurate', 0.5490917067893084),
#  (u'classical', 0.5483779718327962),
#  (u'33', 0.5483550545966674),
#  (u'comparing', 0.5473903442116153),
#  (u'muth\xe9n', 0.5460320233356443),
#  (u'district', 0.5456068439930755),
#  (u'thank', 0.5454731558361354),
#  (u'invitation', 0.5453031242284068),
#  (u'heard', 0.5446960750740132),
#  (u'educational', 0.5446688217827037),
#  (u'sakaguchi', 0.5443678142999188),
#  (u'graham', 0.544089742394008),
#  (u'structural', 0.5439175785525817),
#  (u'publisher', 0.5425389158752425),
#  (u'depression', 0.5422272669681372),
#  (u'personality', 0.5418267062943944),
#  (u'legislature', 0.5389432157257619),
#  (u'\u201cwhat', 0.5386401047878643),
#  (u'yen', 0.5385212421335825),
#  (u'juvonen', 0.5383626350949621),
#  (u'adolescence', 0.5375068441903705),
#  (u'internet', 0.5368995711611385),
#  (u'comprised', 0.536728159835229),
#  (u'foundation', 0.5364108583137625),
#  (u'care', 0.5363071944369805),
#  (u'studd', 0.5360732818206019),
#  (u'structure', 0.5354902591884229),
#  (u'one\u2019s', 0.5346062216695985),
#  (u'approximately', 0.5340356537597667),
#  (u'racial', 0.5339188808657089),
#  (u'according', 0.5336593365778834),
#  (u'thapa', 0.5330746111042339),
#  (u'remember', 0.5327620949262386),
#  (u'detailed', 0.5312225091864534),
#  (u'california', 0.52998776906315),
#  (u'cultural', 0.5292522534067877),
#  (u'selfreport', 0.528563995662088),
#  (u'open', 0.5282500774900298),
#  (u'45', 0.5282182390449605),
#  (u'13', 0.5273969018089868),
#  (u'52', 0.5270221604310601),
#  (u'schoolbased', 0.5269909833171641),
#  (u'status', 0.5266157120347762),
#  (u'nine', 0.5264451086399871),
#  (u'1993', 0.5260765300183989),
#  (u'peskin', 0.524638928738402),
#  (u'independent', 0.5241790278671112),
#  (u'brief', 0.5240131069580741),
#  (u'follows', 0.5240131069580741),
#  (u'serious', 0.5236093215147157),
#  (u'coercion', 0.5233697984785614),
#  (u'which', 0.523265580159534),
#  (u'last', 0.5230061128883209),
#  (u'receiving', 0.522926255835876),
#  (u'antecedent', 0.5228369268793827),
#  (u'trend', 0.5226671835164277),
#  (u'addressed', 0.5225418630629401),
#  (u'katzwise', 0.5222340317233148),
#  (u'racist', 0.5215089735894245),
#  (u'exclusively', 0.5213791635775628),
#  (u'afraid', 0.5211080898792503),
#  (u'23', 0.520268608091917),
#  (u'questionnaire', 0.5194665132406203),
#  (u'commission', 0.5184497222159618),
#  (u'rather', 0.5183542564492377),
#  (u'predicting', 0.5179478631554345),
#  (u'right', 0.5166717858098481),
#  (u'crime', 0.5163649418201665),
#  (u'confident', 0.5162281389569261),
#  (u'project', 0.5158394960404654),
#  (u'hong', 0.5155403050580645),
#  (u'kong', 0.5155403050580645),
#  (u'complaint', 0.5154797622976789),
#  (u'hill', 0.5151401633283286),
#  (u'petersen', 0.514793690982913),
#  (u'message', 0.5145873571331668),
#  (u'interactive', 0.5145491493403275),
#  (u'secondary', 0.5136322411146876),
#  (u'entered', 0.5135515557568041),
#  (u'pornography', 0.5134996628865441),
#  (u'r2', 0.5129533954093666),
#  (u'sociosexual', 0.5127710834878739),
#  (u'hsieh', 0.5125965710623392),
#  (u'transition', 0.5123109625674731),
#  (u'manhood', 0.5121426270140397),
#  (u'sa', 0.5115598137903705),
#  (u'canadian', 0.5113794211803668),
#  (u'fitzgerald', 0.5106501013596942),
#  (u'human', 0.5098164951739974),
#  (u'longitudinal', 0.5096823795036516),
#  (u'propensity', 0.5092749700937098),
#  (u'employment', 0.5089862189620705),
#  (u'stand', 0.5085257558433101),
#  (u'onenight', 0.5085257558433101),
#  (u'remark', 0.5077146650615861),
#  (u'grossman', 0.5076394176834392),
#  (u'sexism', 0.5071913396184516),
#  (u'1991', 0.5070421666659461),
#  (u'continued', 0.5064845939994779),
#  (u'content', 0.5061892819183565),
#  (u'blackwell', 0.5057863569338897),
#  (u'england', 0.5057863569338897),
#  (u'hostile', 0.505552799769628),
#  (u'single', 0.5052805629360528),
#  (u'withdrawal', 0.5045681585957406),
#  (u'allow', 0.5026486262585093),
#  (u'public', 0.5023201312879411),
#  (u'profile', 0.5019241096469272),
#  (u'statistical', 0.500622348308879),
#  (u'd\u2019augelli', 0.4991964253787343),
#  (u'from', 0.4987627306795822),
#  (u'professional', 0.49851311931716474),
#  (u'straight', 0.4979855730182359),
#  (u'teen', 0.49797216310150577),
#  (u'al', 0.4971595242417896),
#  (u'incidence', 0.49639876583585346),
#  (u'clinical', 0.49593391671467263),
#  (u'et', 0.4957642203334318),
#  (u'funding', 0.4956199766515676),
#  (u'bullyvictim', 0.4954665097955193),
#  (u'nyc', 0.49458333175481356),
#  (u'espeland', 0.49288194957305415),
#  (u'strauss', 0.49288194957305415),
#  (u'iannotti', 0.4925037271708355),
#  (u'better', 0.4922189171780934),
#  (u'schmitt', 0.4919398190080658),
#  (u'korchmaros', 0.49038320150026626),
#  (u'cyber', 0.49035254483275886),
#  (u'girls\u2019', 0.4894780076520497),
#  (u'equation', 0.48945645908131336),
#  (u'contrast', 0.48926720610978297),
#  (u'review', 0.4884243127622844),
#  (u'civil', 0.4879737723673714),
#  (u'role', 0.4878487171514911),
#  (u'respond', 0.4874590298254148),
#  (u'opportunity', 0.4858718526735662),
#  (u'equal', 0.4858718526735662),
#  (u'black', 0.48513262014400943),
#  (u'7', 0.4840406727639484),
#  (u'highest', 0.4839550269403069),
#  (u'telephone', 0.4839140272725031),
#  (u'10', 0.4836257868439711),
#  (u'uk', 0.48293106695281834),
#  (u'modeling', 0.48196786324664775),
#  (u'malamuth', 0.48026757788291785),
#  (u'hlm', 0.47971286554577475),
#  (u'gruber', 0.47947109306347524),
#  (u'cyberbullying', 0.4781999309576394),
#  (u'\u2014', 0.47762971929832465),
#  (u'37', 0.4773276058568737),
#  (u'lca', 0.4768281458283939),
#  (u'tactic', 0.47602887428386814),
#  (u'derogation', 0.47602887428386814),
#  (u'ny', 0.475727398749869),
#  (u'attending', 0.47541959831386715),
#  (u'method', 0.47515320523018933),
#  (u'teacher', 0.4750382847498617),
#  (u'offline', 0.4749228166767932),
#  (u'benbenishty', 0.47480508856478937),
#  (u'junior', 0.47462683629874625),
#  (u'hpol', 0.47439246246725314),
#  (u'continuum', 0.47431962314960774),
#  (u'curriculum', 0.4738643524953915),
#  (u'external', 0.47352695387502375),
#  (u'bmi', 0.47350273831640277),
#  (u'socioeconomic', 0.4717931156375842),
#  (u'morbidity', 0.4715525262495779),
#  (u'mortality', 0.4715525262495779),
#  (u'explaining', 0.47117372979979766),
#  (u'soibehavior', 0.47102706290645796),
#  (u'jones', 0.4707591192257543),
#  (u'are', 0.4707119846826693),
#  (u'suicide', 0.47024657234019757),
#  (u'\u201cbullying\u201d', 0.46989953170950627),
#  (u'lenhart', 0.46989458014961566),
#  (u'strategy', 0.4694521121766941),
#  (u'systematic', 0.4688518561416944),
#  (u'reducing', 0.46820842431976034),
#  (u'bias', 0.46820842431976034),
#  (u'sexuality', 0.46805697010905706),
#  (u'huang', 0.4679519146875692),
#  (u'oxford', 0.4674545653007714),
#  (u'engagement', 0.4674329396288475),
#  (u'via', 0.4671579630249064),
#  (u'certain', 0.46663256709351686),
#  (u'mcmaster', 0.46654107105799136),
#  (u'harris', 0.46599865763062026),
#  (u'soi', 0.46586530964249767),
#  (u'and', 0.46496650963898833),
#  (u'\u03c72', 0.46490974046120603),
#  (u'majority', 0.4647001449595968),
#  (u'checklist', 0.46468603115576834),
#  (u'explains', 0.46460644252477057),
#  (u'bennett', 0.4645938924786038),
#  (u'myth', 0.46416424527602657),
#  (u'adhd', 0.4640192670432607),
#  (u'culture', 0.46376031323406236),
#  (u'preliminary', 0.46325844242458425),
#  (u'hamburger', 0.4627809371264828),
#  (u'6', 0.46239528180719963),
#  (u'inappropriate', 0.4619059717412269),
#  (u'access', 0.46184595938077355),
#  (u'\u2013', 0.46184595938077355),
#  (u'subsequent', 0.46145082067856175),
#  (u'implemented', 0.4613841949413533),
#  (u'getting', 0.46127707046324196),
#  (u'primarily', 0.46100090886275347),
#  (u'prevent', 0.4609706254968861),
#  (u'72', 0.4603165459425788),
#  (u'island', 0.46027972614008433),
#  (u'rhode', 0.46027972614008433),
#  (u'design', 0.4591188760330163),
#  (u'hegemonic', 0.4590230902078783),
#  (u'netherlands', 0.45866671568848016),
#  (u'several', 0.4583311981495003),
#  (u'student\u2019s', 0.4577048024614955),
#  (u'adjustment', 0.4575554924092993),
#  (u'\u201csexual', 0.45752379557442646),
#  (u'i', 0.4572656265518293),
#  (u'joint', 0.45688105585996525),
#  (u'attraction', 0.4557116006727489),
#  (u'decreased', 0.45509648692270877),
#  (u'membership', 0.4550935257599083),
#  (u'harm', 0.45445070120522024),
#  (u'participate', 0.4538221113964084),
#  (u'reporting', 0.4536215787057452),
#  (u'adverse', 0.453552232652619),
#  (u'date', 0.45345969201565106),
#  (u'framework', 0.4533340679334547),
#  (u'astor', 0.4533238815604245),
#  (u'discussed', 0.45278884693775423),
#  (u'1999', 0.45236590452423747),
#  (u'sexualized', 0.45231966472801294),
#  (u'testing', 0.45198279536569813),
#  (u'growth', 0.4515664308017921),
#  (u'revealed', 0.4513677468825374),
#  (u'reflect', 0.4513515955066938),
#  (u'hallway', 0.45045692734267156),
#  (u'allows', 0.4504357620168144),
#  (u'such', 0.45036433962389705),
#  (u'prevalent', 0.4499990346600784),
#  (u'significance', 0.44946081020609646),
#  (u'clinic', 0.4492442807261871),
#  (u'medium', 0.44917680583898234),
#  (u'surveillance', 0.4486329111893625),
#  (u'weekly', 0.4486329111893625),
#  (u'physically', 0.44860576390252044),
#  (u'assessed', 0.44859445009954363),
#  (u'demographic', 0.4482592524121613),
#  (u'identified', 0.4476206048101989),
#  (u'solicitation', 0.44699252360036773),
#  (u'developmental', 0.44698447560486254),
#  (u'kann', 0.44677790724346633),
#  (u'gynecology', 0.44676320670693703),
#  (u'obstetrics', 0.44676320670693703),
#  (u'dominance', 0.44622405176957775),
#  (u'relevant', 0.4460993362684728),
#  (u'pacific', 0.44607372916683335),
#  (u'hyde', 0.44593916477813456),
#  (u'sexist', 0.44533338276393414),
#  (u'pubertal', 0.44493304617445456),
#  (u'objectified', 0.44493304617445456),
#  (u'students\u2019', 0.44485921712102927),
#  (u'but', 0.44443213422215777),
#  (u'fineran', 0.4444085178514263),
#  (u'boys\u2019', 0.44347160298055377),
#  (u'teenager', 0.4424341098251095),
#  (u'suggesting', 0.442002048997645),
#  (u'usa', 0.4419264384218973),
#  (u'perceived', 0.4418885933120293),
#  (u'relational', 0.4412547594693176),
#  (u'dynamic', 0.441172929769927),
#  (u'smith', 0.4403677742225865),
#  (u'medical', 0.4401794466606823),
#  (u'terhanian', 0.4400385474188766),
#  (u'bremer', 0.4400385474188766),
#  (u'procedure', 0.43969421433068967),
#  (u'attribute', 0.4395566755992086),
#  (u'stressor', 0.43910963188994),
#  (u'university', 0.4390099051760357),
#  (u'intersection', 0.43887793415213405),
#  (u'null', 0.43813222747453695),
#  (u'harassment\u201d', 0.4379963327660671),
#  (u'beyond', 0.43747618410263406),
#  (u'global', 0.4373756335176823),
#  (u'communication', 0.43669805243069226),
#  (u'separate', 0.4364303051881046),
#  (u'nationally', 0.43641407810049315),
#  (u'uncomfortable', 0.4349511743342761),
#  (u'22', 0.4345975050565823),
#  (u'mental', 0.4345975050565823),
#  (u'alone', 0.4336514392421227),
#  (u'kind', 0.43309810051186043),
#  (u'anonymous', 0.43306316554533564),
#  (u'engage', 0.43294968402030687),
#  (u'bad', 0.43273884304721205),
#  (u'european', 0.4324336316522),
#  (u'almeida', 0.43232521883151015),
#  (u'johnson', 0.43232521883151015),
#  (u'early', 0.4320772672321814),
#  (u'teasing', 0.4320523725087707),
#  (u'van', 0.43203325216492405),
#  (u'considerable', 0.4318042889009239),
#  (u'suggest', 0.43155808650920263),
#  (u'theoretical', 0.43129995348738537),
#  (u'casual', 0.43117324681041147),
#  (u'drasgow', 0.43081246989532956),
#  (u'nansel', 0.43068598238650185),
#  (u'community', 0.43021939278955523),
#  (u'shattuck', 0.4297586174215421),
#  (u'wolak', 0.42963632716350997),
#  (u'percent', 0.4285637750920263),
#  (u'at', 0.42801252862166117),
#  (u'basile', 0.42796049885025506),
#  (u'coded', 0.4277380184358141),
#  (u'subtypes', 0.4277200890136214),
#  (u'health', 0.4273459989634917),
#  (u'\u02db', 0.4271638995433736),
#  (u'family', 0.42681448873804134),
#  (u'numerous', 0.42649754314752314),
#  (u'partly', 0.4264309653412628),
#  (u'interval', 0.4259705734772277),
#  (u'concerning', 0.42595061041571214),
#  (u'disparity', 0.42515771807428454),
#  (u'jama', 0.4247899366468327),
#  (u'documented', 0.4247608089675395),
#  (u'get', 0.4245951420939353),
#  (u'indicated', 0.42363776071542336),
#  (u'dimension', 0.4235626351435833),
#  (u'scantron\xae', 0.42285394871250737),
#  (u'attitudinal', 0.42203916351311843),
#  (u'5', 0.4218121480922491),
#  (u'discrimination', 0.4218093766999224),
#  (u'fit', 0.42162410358242985),
#  (u'performance', 0.42155348136920523),
#  (u'further', 0.4213221183331275),
#  (u'3b', 0.42131211947185754),
#  (u'3a', 0.42131211947185754),
#  (u'life', 0.42094395547538604),
#  (u'analyzed', 0.42070639490002604),
#  (u'frame', 0.4201260439283293),
#  (u'9th', 0.4199646819417512),
#  (u'4', 0.4199317043572642),
#  (u'conflict', 0.4198933780531997),
#  (u'internal', 0.4195944075868402),
#  (u'legal', 0.4192296990217136),
#  (u'create', 0.4192296990217136),
#  (u'retrieved', 0.41895966068932855),
#  (u'administration', 0.41878134146443013),
#  (u'stigma', 0.4184285683861819),
#  (u'valid', 0.41840764133876085),
#  (u'possibility', 0.41812822131220817),
#  (u'process', 0.41776689026114505),
#  (u'highlight', 0.4171300870639013),
#  (u'perspective', 0.41708191252074583),
#  (u'detail', 0.4170489274818791),
#  (u'islander', 0.417039709050263),
#  (u'indicator', 0.41664456527239824),
#  (u'jiang', 0.41591678077180444),
#  (u'nonconforming', 0.41591221502901127),
#  (u'letter', 0.4157915241831321),
#  (u'2008', 0.41522660590947114),
#  (u'88', 0.4141500091169579),
#  (u'israeli', 0.41398250506291656),
#  (u'technology', 0.41391733645257134),
#  (u'exploitability', 0.41337759864716517),
#  (u'adolescents\u2019', 0.41332017689566203),
#  (u'classmate', 0.4128921225429853),
#  (u'vulnerability', 0.4127107480160583),
#  (u'become', 0.4127107480160583),
#  (u'period', 0.41201430990670823),
#  (u'pediatric', 0.4117604253804417),
#  (u'took', 0.4114746762629429),
#  (u'confidence', 0.41123976830938974),
#  (u'pattern', 0.4112165702551108),
#  (u'leading', 0.41082089418805756),
#  (u'organization', 0.41082089418805756),
#  (u'occurring', 0.41066526478517995),
#  (u'informed', 0.4103841427947803),
#  (u'instruction', 0.4103841427947803),
#  (u'perry', 0.41029744102552035),
#  (u'benefit', 0.4101967922037119),
#  (u'completing', 0.4101967922037119),
#  (u'lachman', 0.4100529262744506),
#  (u'emerged', 0.40998645570103626),
#  (u'stress', 0.40994513485627876),
#  (u'messaging', 0.40925721955552463),
#  (u'problem', 0.4091477517959063),
#  (u'hamby', 0.40887037797459896),
#  (u'remained', 0.4086006073011378),
#  (u'bus', 0.4084369712524877),
#  (u'experienced', 0.4079272153287554),
#  (u'thus', 0.4078609344910001),
#  (u'user', 0.4078416788803208),
#  (u'psychology', 0.40744133309046665),
#  (u'perception', 0.40732213193725275),
#  (u'both', 0.40712159668451525),
#  (u'responding', 0.4071159853162184),
#  (u'2000', 0.4069499797128452),
#  (u'together', 0.4068590274614282),
#  (u'taken', 0.4068590274614282),
#  (u'relation', 0.4067948531267451),
#  (u'quality', 0.4066347951639489),
#  (u'complete', 0.4064020466604885),
#  (u'correlate', 0.4062906947119092),
#  (u'maltreatment', 0.40613212117930586),
#  (u'others', 0.4059201980136115),
#  (u'upsetting', 0.4057519480094643),
#  (u'series', 0.4055788431206504),
#  (u'longterm', 0.405421410522736),
#  (u'aggression', 0.40524151596636193),
#  (u'either', 0.4050306265346189),
#  (u'ask', 0.4045512374714561),
#  (u'pathway', 0.40429761641497214),
#  (u'positively', 0.4040919647832854),
#  (u'causality', 0.40384945853381177),
#  (u'inventory', 0.4036609223143091),
#  (u'weighting', 0.4035775279095292),
#  (u'sex', 0.4033155751767598),
#  (u'aggregated', 0.4026020254448985),
#  (u'investigate', 0.4025926317795706),
#  (u'diverse', 0.40237708278234385),
#  (u'empirical', 0.40233044502441845),
#  (u'regard', 0.401841105433667),
#  (u'specifically', 0.40154382664133637),
#  (u'response', 0.4012912272706969),
#  (u'examination', 0.4011352194481662),
#  (u'development', 0.4008475539964278),
#  (u'scale', 0.40081143160263055),
#  (u'zweig', 0.4006750457797567),
#  (u'yahner', 0.4006750457797567),
#  (u'dank', 0.4006750457797567),
#  (u'average', 0.3998384788954367),
#  (u'raceethnicity', 0.39928812226974486),
#  (u'each', 0.3992038241146735),
#  (u'14', 0.3991555412194295),
#  (u'differential', 0.39899313046507423),
#  (u'taiwanese', 0.3985528417924162),
#  (u'legislation', 0.3983320461318004),
#  (u'change', 0.39804383039007624),
#  (u'york', 0.3980032740081052),
#  (u'class', 0.39770058475714803),
#  (u'frequency', 0.39760453307386073),
#  (u'theory', 0.3975530882530262),
#  (u'5th', 0.39751209124664777),
#  (u'minority', 0.3973689985780338),
#  (u'presented', 0.39732135610541197),
#  (u'needed', 0.3971497349834018),
#  (u'statistically', 0.397125585561527),
#  (u'patient', 0.3964737724308214),
#  (u'kde', 0.3964393152240143),
#  (u'addition', 0.39636160838465806),
#  (u'lindberg', 0.396303762718617),
#  (u'grabe', 0.396303762718617),
#  (u'heterosexism', 0.3962449739210537),
#  (u'drug', 0.39618886621281063),
#  (u'furman', 0.3959493932040424),
#  (u'wellbeing', 0.39540898724694246),
#  (u'receive', 0.39454454720955806),
#  (u'aauw', 0.3944856659658704),
#  (u'seem', 0.394225114408382),
#  (u'true', 0.3941554394606733),
#  (u'intervention', 0.3939974912722168),
#  (u'juvenile', 0.39323992501511623),
#  (u'twice', 0.3920213015876047),
#  (u'293', 0.39189420144156206),
#  (u'fairly', 0.3917442493532408),
#  (u'\u03b1', 0.3916807011827973),
#  (u'guardian', 0.39121928224036484),
#  (u'implication', 0.39118978708587426),
#  (u'analytic', 0.3911673848920402),
#  (u'happen', 0.3909069235225598),
#  (u'anywhere', 0.3909069235225598),
#  (u'they', 0.39066187445094447),
#  (u'fewer', 0.3905289676906789),
#  (u'collinsworth', 0.3903551039898384),
#  (u'93', 0.39011741120591376),
#  (u'major', 0.38986673585113624),
#  (u'romantic', 0.38932164399084507),
#  (u'lack', 0.38880950418146987),
#  (u'stein', 0.38858293607714445),
#  (u'only', 0.3885600632534643),
#  (u'restricted', 0.3881004364309585),
#  (u'influence', 0.3879406804052046),
#  (u'followed', 0.38765140538766446),
#  (u'craig', 0.38756247727861787),
#  (u'rv', 0.3874807447791704),
#  (u'green', 0.38737277702040507),
#  (u'dot', 0.38737277702040507),
#  (u'bowen', 0.38703680007613167),
#  (u'stonard', 0.38703680007613167),
#  (u'possible', 0.3866725450554792),
#  (u'noted', 0.3866725450554792),
#  (u'antibullying', 0.3864705407124039),
#  (u'along', 0.3864126480133604),
#  (u'garafalo', 0.38597860020226304),
#  (u'durant', 0.38597860020226304),
#  (u'resource', 0.3859077275410002),
#  (u'notable', 0.38558634433809713),
#  (u'2009a', 0.3854188229338491),
#  (u'2009b', 0.3854188229338491),
#  (u'013', 0.38537124757111685),
#  (u'local', 0.3845935598657396),
#  (u'respect', 0.3841468191198033),
#  (u'cause', 0.383968357925356),
#  (u'evolved', 0.3830796405265342),
#  (u'reproductive', 0.38256150781499587),
#  (u'exposure', 0.3824906424201296),
#  (u'unrestricted', 0.38185269557800827),
#  (u'egalitarian', 0.38174425548544483),
#  (u'representative', 0.38156810058871293),
#  (u'variance', 0.38144870455400154),
#  (u'regarded', 0.38142718026354305),
#  (u'currently', 0.38121122120236517),
#  (u'yet', 0.3811457325245601),
#  (u'adolescent', 0.381038620181895),
#  (u'competing', 0.38101568987732387),
#  (u'larger', 0.38075292013332845),
#  (u'cooccurrence', 0.3805103834168394),
#  (u'direction', 0.37952105223635557),
#  (u'conclusion', 0.37939528228228386),
#  (u'little', 0.37938699527534736),
#  (u'chang', 0.3792564439176157),
#  (u'wei', 0.3790687957183954),
#  (u'self', 0.37888600686953156),
#  (u'account', 0.37788274739507943),
#  (u'hence', 0.377709005471544),
#  (u'williams', 0.3776099814029213),
#  (u'lower', 0.37757480952002215),
#  (u'ideology', 0.37748715577584485),
#  (u'unsafe', 0.37737490827829995),
#  (u'available', 0.3773263841282298),
#  (u'largest', 0.3772241337440894),
#  (u'highly', 0.3771480296500201),
#  (u'continuous', 0.3771480296500201),
#  (u'69', 0.37712250885934634),
#  (u'norm', 0.37683116087217217),
#  (u'relatively', 0.37664489807993623),
#  (u'explored', 0.37657267887230644),
#  (u'miller', 0.37656218036391315),
#  (u'furthermore', 0.37643007373042137),
#  (u'hypothesized', 0.3761614204284186),
#  (u'in', 0.3761566584350431),
#  (u'maker', 0.37609658061845086),
#  (u'abuse', 0.37591464224958054),
#  (u'healthy', 0.37549085255534415),
#  (u'ormerod', 0.3754599759964117),
#  (u'pepler', 0.37531647723173084),
#  (u'latino', 0.37512852489656534),
#  (u'interested', 0.37491371064552154),
#  (u'otherwise', 0.37468759720069716),
#  (u'toward', 0.3745540746472875),
#  (u'middle', 0.37443533663999656),
#  (u'limited', 0.374382192513455),
#  (u'frequent', 0.374131221324956),
#  (u'event', 0.3737649222482334),
#  (u'effort', 0.37373018829893784),
#  (u'sum', 0.37362391129086986),
#  (u'completed', 0.3732887762245296),
#  (u'\u201cin', 0.37304253524876974),
#  (u'r', 0.3729057115211954),
#  (u'largescale', 0.37277352271448405),
#  (u'sexualharassment', 0.3727039684907646),
#  (u'initial', 0.3726586643272073),
#  (u'relationship', 0.3726495002066208),
#  (u'homophobia', 0.3724087976655753),
#  (u'preparation', 0.37233398649184646),
#  (u'prediction', 0.3719638353250423),
#  (u'more', 0.3712185669522999),
#  (u'complex', 0.37088759283195405),
#  (u'externalizing', 0.37053670472055367),
#  (u'hierarchy', 0.3704691195744985),
#  (u'straightheterosexual', 0.3704691195744985),
#  (u'add', 0.3702968107039967),
#  (u'anderson', 0.3701825183233182),
#  (u'mcguire', 0.3701825183233182),
#  (u'sociosexuality', 0.3701011183227055),
#  (u'providing', 0.3697282154177002),
#  (u'dataset', 0.3697002816687966),
#  (u'similarity', 0.36963513796364716),
#  (u'attractive', 0.36955440029485775),
#  (u'yang', 0.36926797327501315),
#  (u'asianpacific', 0.3690548330226736),
#  (u'unwanted', 0.36894558913362496),
#  (u'bully', 0.36894558913362496),
#  (u'excluding', 0.3689223628164927),
#  (u'e', 0.36891127877190316),
#  (u'finkelhor', 0.368626915719842),
#  (u'throughout', 0.3684714073306753),
#  (u'act', 0.36829684386335687),
#  (u'practice', 0.36829215473683236),
#  (u'price', 0.3682250368512911),
#  (u'yrbs', 0.3682090195098995),
#  (u'alternative', 0.36775352573602116),
#  (u'authorship', 0.3675300308626436),
#  (u'perhaps', 0.3672898127023535),
#  (u'ltd', 0.36700961610904115),
#  (u'connolly', 0.3667891300225594),
#  (u'chance', 0.36674771876620726),
#  (u'construct', 0.3665414273285595),
#  (u'when', 0.3664230577937016),
#  (u'definition', 0.3663858654231221),
#  (u'body', 0.3662783964248774),
#  (u'published', 0.3661574759047284),
#  (u'component', 0.3661196175155469),
#  (u'day', 0.3660525738041185),
#  (u'elementary', 0.3657656476888447),
#  (u'tended', 0.3653393370446225),
#  (u'that', 0.3652157227921387),
#  (u'new', 0.36518660977248024),
#  (u'part', 0.3651700095984788),
#  (u'determine', 0.36470206645454684),
#  (u'potentially', 0.3645307865335889),
#  (u'de', 0.3645299818166291),
#  (u'performed', 0.3643150571081899),
#  (u'motivation', 0.36411760956994926),
#  (u'exception', 0.36368169877717116),
#  (u'reported', 0.36352129792266186),
#  (u'reliability', 0.3634675020354817),
#  (u'crossethnic', 0.36339103870467604),
#  (u'measurement', 0.36315198524504494),
#  (u'individual', 0.36272088584504353),
#  (u'case', 0.36269297991716953),
#  (u'masculine', 0.3622290796970691),
#  (u'paradigm', 0.36220525524817443),
#  (u'used', 0.3620298425201521),
#  (u'populationbased', 0.3619826389756534),
#  (u'occur', 0.3618728622143219),
#  (u'exploring', 0.36167034459546515),
#  (u'american', 0.361230905891421),
#  (u'becomes', 0.3610288055898456),
#  (u'list', 0.36091189086747427),
#  (u'made', 0.36089734742387747),
#  (u'score', 0.3608843593853246),
#  (u'multilevel', 0.3608384260064),
#  (u'organizational', 0.3608384260064),
#  (u'wang', 0.3608228416785784),
#  (u'country', 0.3607616482813673),
#  (u'centered', 0.3606503142848886),
#  (u'criterion', 0.35997048638405443),
#  (u'combined', 0.3599634915120739),
#  (u'exploratory', 0.3598798237221209),
#  (u'office', 0.3594676414893122),
#  (u'boyfriend', 0.35945967577270826),
#  (u'girlfriend', 0.35945967577270826),
#  (u'shortterm', 0.3594078336821113),
#  (u'harassing', 0.3591403720255438),
#  (u'source', 0.35912893462239664),
#  (u'observed', 0.3590356351072793),
#  (u'an', 0.35903029981216306),
#  (u'\xa9', 0.3586161329761578),
#  (u'asian', 0.3584432036558626),
#  (u'addressing', 0.3581234770813009),
#  (u'attention', 0.3580878424585905),
#  (u'glsen', 0.35785520980322316),
#  (u'play', 0.35777371124388413),
#  (u'greater', 0.3576714167890736),
#  (u'support', 0.3574517201121847),
#  (u'caregiver', 0.3572065174168238),
#  (u'individuallevel', 0.3571787453279442),
#  (u'disagree', 0.3569579890053874),
#  (u'effect', 0.35691550809846706),
#  (u'multinomial', 0.3566737157337169),
#  (u'moreover', 0.3565940169205454),
#  (u'find', 0.3565401721528834),
#  (u'select', 0.3564375453040174),
#  (u'grouped', 0.35629677471523397),
#  (u'differently', 0.3556387747197094),
#  (u'toomey', 0.35543747501422895),
#  (u'using', 0.3554319317319895),
#  (u'atmosphere', 0.35528253942861426),
#  (u'1988', 0.35511849447876304),
#  (u'race', 0.3549769279271656),
#  (u'emotional', 0.35483615350703623),
#  (u'surveyed', 0.3546850298800558),
#  (u'holt', 0.3545662104486792),
#  (u'stronger', 0.35445757279593293),
#  (u'2007', 0.3543737934302381),
#  (u'address', 0.35384679407252295),
#  (u'beneficial', 0.35382646690832903),
#  (u'participant', 0.3537153855585375),
#  (u'forced', 0.35302748433853703),
#  (u'consent', 0.35298346291843236),
#  (u'behind', 0.3525833742542882),
#  (u'offer', 0.35236695618494945),
#  (u'impact', 0.35235403355047806),
#  (u'examining', 0.3523101864394177),
#  (u'5498', 0.35202389738399376),
#  (u'text', 0.3519142854351122),
#  (u'place', 0.3519032614972201),
#  (u'agree', 0.35189465974513756),
#  (u'emphasis', 0.3518383134696096),
#  (u'influenced', 0.3518297287037489),
#  (u'situation', 0.3518208709839644),
#  (u'outcome', 0.35177731481307634),
#  (u'combination', 0.3515203959540917),
#  (u'special', 0.35144620427738876),
#  (u'elsevier', 0.3513453671711655),
#  (u'reserved', 0.3513453671711655),
#  (u'behavior', 0.35129117258180376),
#  (u'remains', 0.3510730975063957),
#  (u'ratio', 0.3510399564675906),
#  (u'involvement', 0.3507260996107372),
#  (u'aor', 0.3505040371003288),
#  (u'eccles', 0.350278222204154),
#  (u'malanchuk', 0.350278222204154),
#  (u'daviskean', 0.350278222204154),
#  (u'explained', 0.35004654117061307),
#  (u'mean', 0.34980614699971857),
#  (u'latent', 0.3483646498709919),
#  (u'scenario', 0.3479979545056753),
#  (u'of', 0.347873823303846),
#  (u'0001', 0.3477303078035999),
#  (u'function', 0.34770137045303495),
#  (u'want', 0.3474514805700653),
#  (u'gendered', 0.347359226792907),
#  (u'adding', 0.3471859424635483),
#  (u'safe', 0.34710084243800265),
#  (u'palmer', 0.34705486948307146),
#  (u'approach', 0.3469664841548743),
#  (u'varied', 0.3468108442129395),
#  (u'belief', 0.34676886768118914),
#  (u'existing', 0.345676733813348),
#  (u'elevated', 0.34549675558687426),
#  (u'sameethnicity', 0.3454160065483854),
#  (u'site', 0.34529223793142444),
#  (u'upon', 0.3450451647144037),
#  (u'lgbq', 0.3449222538757415),
#  (u'communitybased', 0.3449222538757415),
#  (u'information', 0.34477087529420053),
#  (u'building', 0.34450774514639276),
#  (u'emphasize', 0.34450774514639276),
#  (u'predict', 0.3441147649546837),
#  (u'use', 0.34355548588200374),
#  (u'half', 0.343454923983103),
#  (u'parental', 0.34337056168042784),
#  (u'attracted', 0.343344766763335),
#  (u'same', 0.3431077557227338),
#  (u'comparison', 0.34303571722136256),
#  (u'power', 0.34299556919004376),
#  (u'coefficient', 0.3428865331987652),
#  (u'great', 0.34257195367165344),
#  (u'seen', 0.3425326613625994),
#  (u'291', 0.34241617577348804),
#  (u'controlling', 0.3420230763774646),
#  (u'aspect', 0.34190031605931953),
#  (u'set', 0.34167192227687015),
#  (u'believe', 0.3414750924751112),
#  (u'error', 0.34130652272177164),
#  (u'y', 0.3412824358750554),
#  (u'crook', 0.34120700014105015),
#  (u'jaffe', 0.34120700014105015),
#  (u'physical', 0.3411256794923346),
#  (u'disease', 0.34086443660922755),
#  (u'functioning', 0.34049602804540563),
#  (u'about', 0.3404758747297816),
#  (u'p', 0.3402705579479217),
#  (u'due', 0.3401487810336411),
#  (u'root', 0.3394465600524649),
#  (u'her', 0.3393094510199272),
#  (u'disclosed', 0.33910611870856683),
#  (u'bridge', 0.339074222701048),
#  (u'indicating', 0.33903229431875953),
#  (u'conduct', 0.3387165139780486),
#  (u'greytak', 0.3370392679581489),
#  (u'61', 0.3370045550594535),
#  (u'person', 0.33681250534026086),
#  (u'generally', 0.3357690042191704),
#  (u'large', 0.3357161917241004),
#  (u'western', 0.33570626556739364),
#  (u'diversity', 0.3350348574304756),
#  (u'delinquency', 0.33475252211620654),
#  (u'scored', 0.3345441785487105),
#  (u'answered', 0.3345308490740474),
#  (u'10th', 0.33434110023875874),
#  ...]

# %%
#tfidf using sklearn package
tf = TfidfVectorizer(analyzer='word', ngram_range=(1,1), min_df = 7, stop_words = stop)
tfidf_matrix =  tf.fit_transform(texts)
feature_names = tf.get_feature_names() 
len(feature_names)
# Out:
# 1419

# %%
#sort term scores
dense = tfidf_matrix.todense()
sentences = dense[0].tolist()[0]
phrase_scores = [pair for pair in zip(range(0, len(sentences)), sentences) if pair[1] > 0]
sorted(phrase_scores, key=lambda t: t[1] * -1)
# Out:
# [(964, 0.4021139627019474),
#  (232, 0.309996392008725),
#  (898, 0.28060740912220555),
#  (1372, 0.24780947915884102),
#  (545, 0.2415234569431377),
#  (989, 0.22976042398078805),
#  (1014, 0.22077647826585498),
#  (859, 0.21350623305727703),
#  (773, 0.21277753161132798),
#  (657, 0.20080580954225757),
#  (1185, 0.19064654900343345),
#  (276, 0.1896550757950809),
#  (940, 0.1888743207528982),
#  (33, 0.18183513825274678),
#  (1063, 0.17700913641018537),
#  (906, 0.17507522514044835),
#  (207, 0.17349200600051504),
#  (668, 0.1576375644741868),
#  (1253, 0.15106331789062177),
#  (1250, 0.13233532291785108),
#  (1152, 0.11265257143775669)]

# %%
#Match term ID with term
kwords_dict_3 = {}
sorted_phrase_scores = sorted(phrase_scores, key=lambda t: t[1] * -1)
for phrase, score in [(feature_names[word_id], score) for (word_id, score) in sorted_phrase_scores]:
    kwords_dict_3[phrase] = score
kwords_dict_3
# Out:
# {u'12': 0.18183513825274678,
#  u'adolescents': 0.17349200600051504,
#  u'among': 0.309996392008725,
#  u'based': 0.1896550757950809,
#  u'examine': 0.2415234569431377,
#  u'harassment': 0.20080580954225757,
#  u'high': 0.1576375644741868,
#  u'large': 0.21277753161132798,
#  u'months': 0.21350623305727703,
#  u'occurring': 0.28060740912220555,
#  u'one': 0.17507522514044835,
#  u'past': 0.1888743207528982,
#  u'perpetration': 0.4021139627019474,
#  u'population': 0.22976042398078805,
#  u'prevalence': 0.22077647826585498,
#  u'rates': 0.17700913641018537,
#  u'school': 0.11265257143775669,
#  u'sexual': 0.19064654900343345,
#  u'students': 0.13233532291785108,
#  u'study': 0.15106331789062177,
#  u'victimization': 0.24780947915884102}

# %%
dict_list = [kwords_dict_1, kwords_dict_2, kwords_dict_3, kwords_dict_4, kwords_dict_5]

# %%
cat_list = ['Bully', 'Fight_Assault', 'Sexual Harassment', 'Drug', 'Vandalism']
main_keys = dict(zip(cat_list, dict_list))

# %%
main_keys['Sexual Harassment']
# Out:
# {u'12': 0.18183513825274678,
#  u'adolescents': 0.17349200600051504,
#  u'among': 0.309996392008725,
#  u'based': 0.1896550757950809,
#  u'examine': 0.2415234569431377,
#  u'harassment': 0.20080580954225757,
#  u'high': 0.1576375644741868,
#  u'large': 0.21277753161132798,
#  u'months': 0.21350623305727703,
#  u'occurring': 0.28060740912220555,
#  u'one': 0.17507522514044835,
#  u'past': 0.1888743207528982,
#  u'perpetration': 0.4021139627019474,
#  u'population': 0.22976042398078805,
#  u'prevalence': 0.22077647826585498,
#  u'rates': 0.17700913641018537,
#  u'school': 0.11265257143775669,
#  u'sexual': 0.19064654900343345,
#  u'students': 0.13233532291785108,
#  u'study': 0.15106331789062177,
#  u'victimization': 0.24780947915884102}

# %%
import json
json.dump(main_keys, open('main_keys', 'wb'))
